# %% [markdown]
# #Speech Emotion Recognition
# ##Using Parallelzing CNNs and Transforner-Encoders

# %% [markdown]
# #### Setup

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
#google colab has an old version of librosa with missing mel spectrogram args (for MFCC); upgrade to current
# !pip install -U librosa

# %%
# needed to import dataset from google drive into colab 
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# copy RAVDESS dataset from gdrive and unzip
# !cp '/content/gdrive/MyDrive/machine learning datasets/ravdess.zip' .
# !unzip -q ravdess.zip

# %%
import zipfile
with zipfile.ZipFile('/content/gdrive/MyDrive/machine learning datasets/ravdess.zip', 'r') as zip_ref:
    zip_ref.extractall(path='./data')

# %% [markdown]
# ## Define features

# %%
# RAVDESS native sample rate is 48k
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform, 
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):
    
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform, 
        sr=sample_rate, 
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2)
    
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)
    
    return melspectrogram

def feature_mfcc(
    waveform, 
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames 
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform, 
        sr=sample_rate, 
        n_mfcc=n_mfcc,
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        #hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2
        ) 

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress 
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
    
    # return all features from list of waveforms
    return features

def get_waveforms(file):
    
    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return a single file's waveform                                      
    return waveform_homo
    
# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'
}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %% [markdown]
# ## Loading Data

# %%
# path to data for glob
data_path = './Actor_*/*.wav'

def load_data():
    # features and labels
    emotions = []
    # raw waveforms to augment later
    waveforms = []
    # extra labels
    intensities, genders = [],[]
    # progress counter
    file_count = 0
    for file in glob.glob(data_path):
        # get file name with labels
        file_name = os.path.basename(file)
        
        # get emotion label from the sample's file
        emotion = int(file_name.split("-")[2])

        #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
        if emotion == 8: emotion = 0 # surprise is now at 0 index; other emotion indeces unchanged

        # can convert emotion label to emotion string if desired, but
        # training on number is better; better convert to emotion string after predictions are ready
        # emotion = emotions_dict[str(emotion)]
        
        # get other labels we might want
        intensity = emotion_attributes[file_name.split("-")[3]]
        # even actors are female, odd are male
        if (int((file_name.split("-")[6]).split(".")[0]))%2==0: 
            gender = 'female' 
        else: 
            gender = 'male'
            
        # get waveform from the sample
        waveform = get_waveforms(file)
        
        # store waveforms and labels
        waveforms.append(waveform)
        emotions.append(emotion)
        intensities.append(intensity) # store intensity in case we wish to predict
        genders.append(gender) # store gender in case we wish to predict 
        
        file_count += 1
        # keep track of data loader's progress
        print('\r'+f' Processed {file_count}/{1440} audio samples',end='')
        
    return waveforms, emotions, intensities, genders

# %%
# load data 
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 1440/1440 audio samples

# %% [markdown]
# ## Check extracted audio waveforms and labels:

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1440 samples
# Waveform signal length: 144000
# Emotions set: 1440 sample labels

# %% [markdown]
# ## Splitting into Train/Validation/Test Sets

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets 
for emotion_num in range(len(emotions_dict)):
        
    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility 
    np.random.seed(69)
    # shuffle indicies 
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets 
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array 
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array 
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1147, 144000), y_train:(1147,)
# Validation waveforms:(143, 144000), y_valid:(143,)
# Test waveforms:(150, 144000), y_test:(150,)
#
# Sets are unique: 1440 samples out of 1440 are unique

# %% [markdown]
# Feature extraction

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1147/1147 waveforms
#
# Validation waveforms:
#  Processed 143/143 waveforms
#
# Test waveforms:
#  Processed 150/150 waveforms
#
# Features set: 1440 total, 1147 train, 143 validation, 150 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ## Augmenting the Data with AWGN - Additive White Gaussian Noise

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30): 
    
    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)
    
    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))
    
    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant
    
    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len
    
    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)
    
    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise 
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product 
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise
    
    return multiple_augmented_waveforms

# %%
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1
        
        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)
    
    return features, emotions

# %% [markdown]
# ### Compute AWGN-augmented features and add to the rest of the dataset

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)

print('\n\nValidation waveforms:') # augment waveforms of validation set
features_valid, y_valid = augment_waveforms(X_valid, features_valid, y_valid, multiples)

print('\n\nTest waveforms:') # augment waveforms of test set 
features_test, y_test = augment_waveforms(X_test, features_test, y_test, multiples)

# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 1147/1147 waveforms for 2294/2294 new augmented samples
#
# Validation waveforms:
# Processed 143/143 waveforms for 286/286 new augmented samples
#
# Test waveforms:
# Processed 150/150 waveforms for 300/300 new augmented samples
#
# Native + Augmented Features set: 4320 total, 3441 train, 429 validation, 450 test samples
# 3441 training sample labels, 429 validation sample labels, 450 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ### Check Augmented Waveforms:

# %%
# pick a random waveform, but same one from native and augmented set for easier comparison
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveplot(waveforms[12], sr=sample_rate)
plt.title('Native')

plt.subplot(1, 2, 2)
# augmented waveforms are 2D len 1440 list with 2 waveforms in each position
librosa.display.waveplot(augmented_waveforms_temp[0][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveplot(augmented_waveforms_temp[2][0], sr=sample_rate)
plt.title('AWGN Augmented')

plt.subplot(1, 2, 2)
librosa.display.waveplot(augmented_waveforms_temp[7][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

# %% [markdown]
# Looks noisy alright. Noise is clearly visible in otherwise-silent regions of the waveform. We can see the variability of the noise, which should have an SNR between 15 and 30.
#
# **Note that augmentation was only done after splitting data into train, validation, and test sets - and we processed each set separately.**
#
# **When we augmented the data before splitting it, test and validation data leaked into the training set giving a 97% test accuracy after training.**
#
# ## Format Data into Tensor Ready 4D Arrays
# We don't have a colour channel in our MFCC feature array of dim (#samples, #MFC coefficients, time steps). **We have an analog of a black and white image: instead of 3 colour channels, we have 1 signal intensity channel: magnitude of each of 40 mel frequency coefficients at time t.**
#
# **We need an input channel dim to expand to output channels using CNN filters. We create a dummy channel dim to expand features into 2D-CNN-ready 4D tensor format: N x C x H x W.**

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with 
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (3441, 1, 40, 282) train, (429, 1, 40, 282) validation, (450, 1, 40, 282) test
# Shape of emotion labels: (3441,) train, (429,) validation, (450,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms 
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %% [markdown]
# ## Feature Scaling
# Scaling will drastically decrease the length of time the model needs to train to convergence - it will have easier computations to perform on smaller magnitudes. **For reference, scaling reduces the time to convergence from about 500 to 200 epochs for this model.**
#
# **Standard Scaling makes the most sense because we have features whose target distribution we don't know.** When I performed classification on this dataset with an MLP classifier standard scaling was best across a variety of conditions and features.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back 
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1)) 
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(3441, 1, 40, 282), y_train:(3441,)
# X_valid scaled:(429, 1, 40, 282), y_valid:(429,)
# X_test scaled:(450, 1, 40, 282), y_test:(450,)

# %% [markdown]
# ## Save and Reload Data as NumPy Arrays
# We can save the training/validation/test data as numpy arrays to enable faster loading in case the notebook kernel crashes / google colab runtime crashes / any number of reasons the training data might be cleared from memory. This is much faster than loading 1440 files and computing their features again - not to mention augmented features.

# %%
###### SAVE #########
# choose save file name 
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name 
filename = 'features+labels.npy'

# open file in read mode and read data 
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(3441, 1, 40, 282), y_train:(3441,)
# X_valid:(429, 1, 40, 282), y_valid:(429,)
# X_test:(450, 1, 40, 282), y_test:(450,)

# %% [markdown]
# # Architecture Overview
# <img src="https://github.com/IliaZenkov/transformer-cnn-emotion-recognition/blob/main/notebooks/reports/cnn-transformer-final.png?raw=1">
# As a whole, the CNN architecture of this network is inspired by a combination of the golden standards in image and sequence processing over the last few years.
#
# Each 3-layer deep 2D convolutional block is extremely similar to the **classic [LeNet](http://yann.lecun.com/exdb/publis/pdf/lecun-98.pdf) architecture: Conv->Pool>Conv>Pool>FC.**
#
# **[AlexNet](https://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf) forms the basis for increasing the complexity of feature maps with channel expansion through stacked CNN layers; [Inception and GoogLeNet](https://static.googleusercontent.com/media/research.google.com/en//pubs/archive/43022.pdf) are the inspiration for parallelizing CNN layers in the hopes of diverisfying the features learned by the network.**
#
# **[VGGNet](https://arxiv.org/pdf/1409.1556.pdf) proved the unreasonable efficiency of using fixed sized kernels throughout deeply stacked CNN layers;** I found this to extend to this task. Specifically, VGG saw an improvement over AlexNet largely by replacing large kernels (i.e. 11x11 stride 5) with smaller ones of 3x3 stride 1. One of the motivations that VGG cites for this is that the 3x3 kernel is the smallest kernel size choice in understanding spatial data w.r.t. up/down/left/right (although VGG also uses 1x1 kernels). VGGNet also inspires the maxpool kernel size of 2x2 stride 2, as I have used at the first layer of each convolutional block.
#
# To be more precise, the motivation to use small stacked filters is two-fold: Computational efficiency and expressivity of feature representation. When we stack 3 3x3 kernels on top of eachother as in this architecture, the second layer has a 5x5 view of the original input volume, and the 3rd layer a 7x7 view. However, the nonlinearities between each smaller layer convey more complex feature representations, whereas a single 7x7 layer would only perform a linear transformation itself. Furthermore, if we keep channel (C) consistent between layers, then 3 3x3 kernels are parameterized by (3(C(3x3xC)) = 27C^2 parameters, while just one 7x7 kernel needs C(7x7xC) = 49C^2 parameters. **Ultimately, small stacked kernels appear to be both more powerful and efficient - although, in [Large Kernel Matters -
# Improve Semantic Segmentation by Global Convolutional Network](https://arxiv.org/pdf/1703.02719.pdf), the authors conclude that a larger kernel outperforms smaller stacked kernels for semantic segmentation - however, since we are just doing the semantic part (classification) and don't care about "where" the emotion is - this shouldn't apply.**
#
# Finally, the original [2015 Batch Normalization (BN) paper](https://arxiv.org/abs/1502.03167) suggests that "We add the BN transform immediately before the nonlinearity" i.e. before ReLU; however, **I achieved better performance out of this architechture using BN after ReLU. See Keras author's [Francois Chollet's response on GitHub](https://github.com/keras-team/keras/issues/1802#issuecomment-187966878) regarding the BN order issue: "I can guarantee that recent code written by Christian \[Szegedy\] applies relu before BN".**
#
# The Transformer architecture is precisely as in Viswani et al, 2017: Attention is All You Need, but I use 4 stacked encoders instead of 6 as in their paper. For more details on the Transformer block: [Appendix B: The Transformer and Self-Attention (is All You Need)](#Appendix-B:-The-Transformer-and-Self-Attention-(is-All-You-Need))
#
# # CNN Motivation
# **CNNs with 2D convolutional layers are the gold standard for image processing**, other than the recent advances in the Transformer for images. 2D convolution layers accept input feature maps in a (N,C,H,W) (batch size, channel, height, width) format. We have 4320 MFCC plots - 1440 native and 2880 noise augmented - each MFCC plot is of shape 40x282 with 40 MFC coefficients representing different mel pitch ranges, with 282 timesteps for each MFC coefficient. **We can imagine MFCC plots to be a black and white image with 1 signal intensity channel.** Our MFCC input feature tensor will thus be of shape (4320, 1, 40, 282) before splitting for training. I'm going to refer to input/output feature maps and input/output volumes interchangeably, but they have the same meaning. After an activation function operates on a feature map, it produces an activation map.
#
# I'm using 3x3 kernels in all 3 layers in both CNN blocks. The first layer only has a single input channel creating a 1x3x3 filter, with 16 output channels necessitating 16 such unique 1x3x3 filters with 1x3x3=9 weights per filter. The next layer has 16 input channels and 32 output channels, producing 32 unique 16x3x3 filters, *each* filter having 16x3x3 = 144 weights. That is, the second layer is applying 32 differently weighted 16x3x3 filters to an input volume of 16x20x141 (the 2x2 maxpooled output of the first layer), producing an output feature map of 32x5x35 after 4x4 stride 4 maxpooling. The last layer has 32 input channels, so a 32x3x3 filter, and 64 output channels, so 64 unique such filters with 32x3x3=288 weights each. The last layer produces an output feature map of 64x1x8 after 4x4 stride 4 maxpooling. **I hope that the simultaneous expansion of filter depth/complexity and reduction of feature map volume will provide the most expressive hierarchical feature representation at the lowest computational cost.**
#
# **The key motivations and operations of a 2D Convolutional Neural Net are described in detail in [Appendix A: Convolutional Neural Nets Dissected](#Appendix-A:-Convolutional-Neural-Nets-Dissected) in order to explain the motivation behind the necessity of the CNN for this task and the considerations to take when optimizing the hyperparameters of each layer in a CNN.**
#
# # Transformer-Encoder Motivation
#
# **I use the Transformer-Encoder layer as introduced in [Attention is All You Need](https://arxiv.org/abs/1706.03762) with the hopes that the network will learn to predict frequency distributions of different emotions according to the global structure of the MFCCs of each emotion.** I could have used LSTM-RNNs to learn the sequence of the spectrogram for each emotion, but the network would only learn to predict frequency changes according to adjacent time steps; in contrast, the multi-head self-attention layers of the transformer enable the network to look at multiple previous time steps when predicting the next. This made sense to me because emotions colour the entire sequence of frequencies, not just at one timestep.
#
# **I maxpool the input MFCC map to the transformer block to drastically reduce the number of parameters the network needs to learn.**
#
# **The key motivations and operations behind the Transformer architecture are described in detail in [Appendix B: The Transformer](#Appendix-B:-The-Transformer)**

# %% [markdown]
# # Build Model Architecture and Define Forward Pass

# %%
#change nn.sequential to take dict to make more readable 
import threading
class parallel_all_you_want(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__() 
        
        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer 
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        
        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4, 
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )
        
        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)
        
        ############### 1ST PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock1 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )

        ################# FINAL LINEAR BLOCK ####################
        # Linear softmax layer to take final concatenated embedding tensor 
        #    from parallel 2D convolutional and transformer blocks, output 8 logits 
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array 
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2+40 == 1064 input features --> 8 output emotions 
        self.fc1_linear = nn.Linear(512*2+40,num_emotions) 
        
        ### Softmax layer for the 8 output logits from final FC linear layer 
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
        
    # define one complete parallel fwd pass of input feature tensor thru 2*conv+1*transformer blocks
    def forward(self,x):
        
        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers


          
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1) 
        
        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1) 
        
         
        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        
        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1) 
        
        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)
        
        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        
        ############# concatenate freq embeddings from convolutional and transformer blocks ######
        # concatenate embedding tensors output by parallel 2*conv and 1*transformer blocks
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)  

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)  
        
        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)
        
        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %% [markdown]
# ## Analyzing The Flow of Tensors Through the Network
# We zero-pad 1 the input feature map to each convolutional layer to get back from the layer the same shape tensor as we input: zero-pad 1 adds 2 to each of (H, W) dims, and the 3x3, stride 1 kernels cuts off (kernel - stride == 2) dims from each of (H,W). **Zero-pad 1 --> 3x3 stride 1 kernel effectively throws away the zero pads to get same input/output shape from each conv2D block.**
#
# At the end of first convolutional layer in each block we have a maxpool kernel of size 2x2, stride 2 which will take 1 of 4 pixels in its winddow. For the first input feature map the maxpool kernel will progress 40/2 = 20 times over the rows and 282/2=141 times over the columns, producing a 20x141 output map. **Nonoverlapping maxpool kernels reduce each output dim to _input dim / kernel size_.** We then expand the output channels to 16 making an output feature map of (16x20x141).
#
# The next two convolutional layers in each block have a maxpool kernel size 4x4, stride 4. Same math as above, maxpool reduces each dim/4. 2nd conv layer takes (16x20x141) --> (32x5x35). 3rd and final conv layer takes (32x5x35) --> (64x1x8).
#
# **Note that in (N,C,H,W) format, for MFCCs H = MFCC (pitch),  W = time step.**
#
# **Complete flow through each convolutional block (C,H,W):**
#
#     Layer 1 ---> 1x40x282 --> PAD-1 --> 1x42x284 --> FILTER 1x3x3 --> 16x40x282 --> MAXPOOL 2x2 stride 2 --> 16x20x141
#
#     Layer 2 ---> 16x20x141 --> PAD-1 --> 16x22x143 --> FILTER 16x3x3 --> 32x20x141 --> MAXPOOL 4x4 stride 4 --> 32x5x35
#
#     Layer 3 ---> 32x5x35 --> PAD-1 --> 32x7x37 --> FILTER 32x3x3 --> 64x5x35 --> MAXPOOL 4x4 stride 4 --> 64x1x8
#
#     Flatten ---> 64x1x8 --> Final convolutional embedding length 512 1D array
#
#
# **Complete flow through transformer encoder block (C,H,W):**
#
#     Maxpool 1x4 stride 1x4 ---> 1x40x282 --> 1x20x70
#
#     Drop channel ---> 1x20x70 --> 20x70 (H,W)
#
#     Change dims ---> 20x70 --> 70x40 (W,H)
#
#     4xTransformer encoder ---> 70x40 --> 2x40 (W,H)
#
#     Time average ---> 2x40 --> 1x40 --> Final transformer embedding length 40 1D array
#
# **FC Linear network (C,H,W):**
#
#     Concatenate ---> 512+512+40 --> 1064
#
#     FC Linear layer ---> 1064 --> Final linear logits output length 8 1D array
#
#     Softmax layer: 8 ----> 1 predicted emotion / max probability class
#
#
# We can confirm our network's tensor shapes and flow using the excellent torchsummary package which provides a PyTorch implementation of Keras' model.summary method:

# %%
from torchsummary import summary

# need device to instantiate model
device = 'cuda'

# instantiate model for 8 emotions and move to GPU 
model = parallel_all_you_want(len(emotions_dict)).to(device)

# include input feature map dims in call to summary()
summary(model, input_size=(1,40,282))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-a43107de42cb> in <module>
#       8
#       9 # include input feature map dims in call to summary()
# ---> 10 summary(model, input_size=(1,40,282))
#
# /usr/local/lib/python3.7/dist-packages/torchsummary/torchsummary.py in summary(model, input_size, batch_size, device)
#      70     # make a forward pass
#      71     # print(x.shape)
# ---> 72     model(*x)
#      73
#      74     # remove these hooks
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-60-687bcc8796f7> in forward(self, x)
#     158
#     159         # finally, pass reduced input feature map x into transformer encoder layers
# --> 160         transformer_output = self.transformer_encoder(x)
#     161
#     162         # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1146             input = bw_hook.setup_input_hook(input)
#    1147
# -> 1148         result = forward_call(*input, **kwargs)
#    1149         if _global_forward_hooks or self._forward_hooks:
#    1150             for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/transformer.py in forward(self, src, mask, src_key_padding_mask)
#     236                 output = mod(output, src_mask=mask)
#     237             else:
# --> 238                 output = mod(output, src_mask=mask, src_key_padding_mask=src_key_padding_mask)
#     239
#     240         if convert_to_nested:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1146             input = bw_hook.setup_input_hook(input)
#    1147
# -> 1148         result = forward_call(*input, **kwargs)
#    1149         if _global_forward_hooks or self._forward_hooks:
#    1150             for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/transformer.py in forward(self, src, src_mask, src_key_padding_mask)
#     461             x = x + self._ff_block(self.norm2(x))
#     462         else:
# --> 463             x = self.norm1(x + self._sa_block(x, src_mask, src_key_padding_mask))
#     464             x = self.norm2(x + self._ff_block(x))
#     465
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/transformer.py in _sa_block(self, x, attn_mask, key_padding_mask)
#     472                            attn_mask=attn_mask,
#     473                            key_padding_mask=key_padding_mask,
# --> 474                            need_weights=False)[0]
#     475         return self.dropout1(x)
#     476
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1149         if _global_forward_hooks or self._forward_hooks:
#    1150             for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
# -> 1151                 hook_result = hook(self, input, result)
#    1152                 if hook_result is not None:
#    1153                     result = hook_result
#
# /usr/local/lib/python3.7/dist-packages/torchsummary/torchsummary.py in hook(module, input, output)
#      21             if isinstance(output, (list, tuple)):
#      22                 summary[m_key]["output_shape"] = [
# ---> 23                     [-1] + list(o.size())[1:] for o in output
#      24                 ]
#      25             else:
#
# /usr/local/lib/python3.7/dist-packages/torchsummary/torchsummary.py in <listcomp>(.0)
#      21             if isinstance(output, (list, tuple)):
#      22                 summary[m_key]["output_shape"] = [
# ---> 23                     [-1] + list(o.size())[1:] for o in output
#      24                 ]
#      25             else:
#
# AttributeError: 'NoneType' object has no attribute 'size'

# %% [markdown]
# ## Define Loss/Criterion
#
# We must define the loss function (criterion per PyTorch notation) for the backwards pass of each training iteration. Since our classes our balanced we don't need to specify a class-weight parameter (to balance classes).
#
# **PyTorch nn.CrossEntropyLoss() implements log softmax and negative log likelihood loss (nn.NLLoss() --> nn.LogSoftmax())
# We use log softmax for computation benefits and faster gradient optimization. Log softmax heavily penalizes the model when failing to predict the correct class.**

# %%
# define loss function; CrossEntropyLoss() fairly standard for multiclass problems 
def criterion(predictions, targets): 
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %% [markdown]
# ## Choose Optimizer
#
# I used Adam to train an MLP due to its faster compute and convergence. Adam is great and usually works well with defaults.
#
# **However, a lot of 2018-2020 papers still use SGD. It seems to me that the reason is SGD with properly tuned momentum sometimes (often) converges to lower loss with enough training.**
#
# **Quoting [Wilson et al, 2017](https://arxiv.org/abs/1705.08292):**
#
#     “We observe that the solutions found by adaptive methods generalize worse (often significantly worse) than SGD, even
#     when these solutions have better training performance. These results suggest that practitioners should reconsider the
#     use of adaptive methods to train neural networks."
#
#
# "Adaptive methods" refers to the likes of Adam.
#
# **I took full advantage of plain old SGD by using the highest momentum leading to convergence, plus a generously long training time.**

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %% [markdown]
# ## Define Training Step
#
# We define a function to return a single training step defining one iteration of our model.
#
#     Forward pass output logits and softmax probabilities.
#
#     Record the softmax probabilities to track accuracy.
#
#     Pass output logits to loss function to compute loss.
#
#     Call backwards pass with loss function (backpropogate errors).
#
#     Tell optimizer to apply one update step to network parameters.
#
#     Zero the accumulated gradient in the optimizer for next iteration.

# %%
# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):
    
    # define the training step of the training phase
    def train_step(X,Y):
        
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y) 
        
        # compute gradients for the optimizer to use 
        loss.backward()
        
        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()
        
        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad() 
        
        return loss.item(), accuracy*100
    return train_step

# %% [markdown]
# ## Define Validation Step
#
# Define a function to return a single validation step on the 10% X,y tensor pair to get an idea of our model's generalizibiliy as it trains so we know whether and when to stop it and tune hyperparameters. **Make sure we _do not_ update network parameters during validation by setting model to validation mode. Do not waste resources computing gradients in validation phase by setting torch.no_grad().**

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):
        
        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase: 
        with torch.no_grad(): 
            
            # set model to validation phase i.e. turn off dropout and batchnorm layers 
            model.eval()
      
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            
            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)
            
        return loss.item(), accuracy*100, predictions
    return validate

# %% [markdown]
# # Make Checkpoint Functions
# It's a good idea to save checkpoints of the model state after each epoch. We'll then interrupt training when satisfied with the model's performance and load the appropriate model binary.
#
# - Resume training if hardware/software fails
# - Save compute re-training by training from checkpoint after tuning
# - Implement early stopping easily by keeping snapshot of most performant version of model
# - Google Colab throttles GPU usage eventually; can't keep re-training from scratch indefinitely

# %%
def make_save_checkpoint(): 
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %% [markdown]
# # Build Training Loop
#
# Build the complete training loop using the training and validation step functions.
#
# This model is not reasonable to train on CPU, but it's a good way to check if the model compiled successfully. I'm using Google Colab's free GPU (K80 - 24GB RAM ~2.9 TFLOPs). This model is pretty big (383,688 params to learn if I've checked the math correctly) but trains to convergence within ~10 minutes on a K80.
#
# Pick the number of epochs (complete pass of all training samples) to use that is higher than reasonable so the model does not terminate just before convergence - I manually stopped it when it converges.
#
# **Minibatch size:** [From Yann LeCun's twitter](https://twitter.com/ylecun/status/989610208497360896?lang=en) (with LeCun facebook comment appended) [citing this 2018 minibatch paper](https://arxiv.org/abs/1804.07612):
#
#
#
#     "Training with large minibatches is bad for your health. More importantly, it's bad for your test error. Friends dont
#     let friends use minibatches larger than 32. Let's face it: the only people have switched to minibatch sizes larger than one since 2012 is because GPUs are inefficient for batch sizes smaller than 32. That's a terrible reason. It just means our hardware sucks."
#
#
#
# <br>
# That's about it for the logic. Here's the full training loop:
#
#     --Setup--
#
#     Instantiate model.
#
#     Instantiate training and validation steps with model, loss function, and optimizer.
#
#     Move model to GPU.
#
#         --Epoch--
#
#         Set model to train mode after each post-epoch validation phase completes.
#
#         Shuffle the training set for each  epoch, reset epoch loss and accuracy.
#
#             --Iteration--
#
#             Create X_train, y_train minibatch tensors for each iteration and move tensors to GPU.
#
#             Take 1 train step with X_train, y_train minibatch tensors.
#
#             Aggregate accuracy and loss from each iteration, but only record after each epoch.
#
#         --Epoch--
#
#         Compute and record validation accuracy for the entire epoch to keep track of learning progress.
#
#         Print training metrics after each epoch.

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=len(emotions_dict)).to(device) 
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function 
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):
        
        # set model to train phase
        model.train()         
        
        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size) 
        
        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:] 
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate 
        epoch_acc = 0 
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)
        
        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):
            
            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch 
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size) 
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start 
            
            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:] 
            # get training minibatch labels 
            Y = Y_train[batch_start:batch_end] 

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float() 
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor) 
            
            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            
            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')
        
        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
                  
        # Save checkpoint of the model
        checkpoint_filename = '/content/gdrive/MyDrive/models/checkpoints/audioparallel-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)
        
        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cuda selected
# Number of trainable params:  248488

# %% [markdown]
# ### Train Model

# %%
# choose number of epochs higher than reasonable so we can manually stop training 
num_epochs = 500

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 106/107
# Epoch 0 --- loss:3.282, Epoch accuracy:26.56%, Validation loss:1.908, Validation accuracy:27.74%
# Epoch 1: iteration 106/107
# Epoch 1 --- loss:1.612, Epoch accuracy:38.83%, Validation loss:1.703, Validation accuracy:39.16%
# Epoch 2: iteration 106/107
# Epoch 2 --- loss:1.485, Epoch accuracy:44.09%, Validation loss:1.778, Validation accuracy:39.63%
# Epoch 3: iteration 106/107
# Epoch 3 --- loss:1.400, Epoch accuracy:48.94%, Validation loss:1.537, Validation accuracy:44.52%
# Epoch 4: iteration 106/107
# Epoch 4 --- loss:1.280, Epoch accuracy:51.76%, Validation loss:1.373, Validation accuracy:48.25%
# Epoch 5: iteration 106/107
# Epoch 5 --- loss:1.220, Epoch accuracy:54.46%, Validation loss:1.266, Validation accuracy:51.75%
# Epoch 6: iteration 106/107
# Epoch 6 --- loss:1.169, Epoch accuracy:55.88%, Validation loss:1.246, Validation accuracy:52.45%
# Epoch 7: iteration 106/107
# Epoch 7 --- loss:1.080, Epoch accuracy:59.34%, Validation loss:1.320, Validation accuracy:52.21%
# Epoch 8: iteration 106/107
# Epoch 8 --- loss:1.037, Epoch accuracy:61.32%, Validation loss:1.402, Validation accuracy:53.38%
# Epoch 9: iteration 106/107
# Epoch 9 --- loss:0.969, Epoch accuracy:63.59%, Validation loss:1.237, Validation accuracy:55.48%
# Epoch 10: iteration 106/107
# Epoch 10 --- loss:0.876, Epoch accuracy:66.23%, Validation loss:1.235, Validation accuracy:56.88%
# Epoch 11: iteration 106/107
# Epoch 11 --- loss:0.854, Epoch accuracy:68.35%, Validation loss:1.088, Validation accuracy:59.67%
# Epoch 12: iteration 106/107
# Epoch 12 --- loss:0.772, Epoch accuracy:71.43%, Validation loss:1.092, Validation accuracy:57.81%
# Epoch 13: iteration 106/107
# Epoch 13 --- loss:0.741, Epoch accuracy:72.28%, Validation loss:1.061, Validation accuracy:62.94%
# Epoch 14: iteration 106/107
# Epoch 14 --- loss:0.667, Epoch accuracy:75.09%, Validation loss:1.039, Validation accuracy:60.84%
# Epoch 15: iteration 106/107
# Epoch 15 --- loss:0.647, Epoch accuracy:75.59%, Validation loss:1.243, Validation accuracy:56.88%
# Epoch 16: iteration 106/107
# Epoch 16 --- loss:0.593, Epoch accuracy:78.06%, Validation loss:1.017, Validation accuracy:64.10%
# Epoch 17: iteration 106/107
# Epoch 17 --- loss:0.561, Epoch accuracy:79.77%, Validation loss:1.175, Validation accuracy:58.04%
# Epoch 18: iteration 106/107
# Epoch 18 --- loss:0.550, Epoch accuracy:79.72%, Validation loss:1.100, Validation accuracy:63.40%
# Epoch 19: iteration 106/107
# Epoch 19 --- loss:0.486, Epoch accuracy:82.56%, Validation loss:1.191, Validation accuracy:62.94%
# Epoch 20: iteration 106/107
# Epoch 20 --- loss:0.485, Epoch accuracy:81.72%, Validation loss:1.097, Validation accuracy:65.97%
# Epoch 21: iteration 106/107
# Epoch 21 --- loss:0.441, Epoch accuracy:83.67%, Validation loss:1.040, Validation accuracy:65.97%
# Epoch 22: iteration 106/107
# Epoch 22 --- loss:0.428, Epoch accuracy:83.78%, Validation loss:1.330, Validation accuracy:60.37%
# Epoch 23: iteration 106/107
# Epoch 23 --- loss:0.392, Epoch accuracy:85.59%, Validation loss:1.093, Validation accuracy:65.27%
# Epoch 24: iteration 106/107
# Epoch 24 --- loss:0.373, Epoch accuracy:86.14%, Validation loss:1.141, Validation accuracy:63.40%
# Epoch 25: iteration 106/107
# Epoch 25 --- loss:0.357, Epoch accuracy:86.81%, Validation loss:1.038, Validation accuracy:64.80%
# Epoch 26: iteration 106/107
# Epoch 26 --- loss:0.339, Epoch accuracy:87.62%, Validation loss:1.296, Validation accuracy:62.94%
# Epoch 27: iteration 106/107
# Epoch 27 --- loss:0.351, Epoch accuracy:86.89%, Validation loss:1.071, Validation accuracy:67.13%
# Epoch 28: iteration 106/107
# Epoch 28 --- loss:0.308, Epoch accuracy:89.01%, Validation loss:1.208, Validation accuracy:61.77%
# Epoch 29: iteration 106/107
# Epoch 29 --- loss:0.301, Epoch accuracy:88.96%, Validation loss:1.069, Validation accuracy:68.53%
# Epoch 30: iteration 106/107
# Epoch 30 --- loss:0.295, Epoch accuracy:88.78%, Validation loss:1.156, Validation accuracy:65.50%
# Epoch 31: iteration 106/107
# Epoch 31 --- loss:0.294, Epoch accuracy:88.81%, Validation loss:1.139, Validation accuracy:65.27%
# Epoch 32: iteration 106/107
# Epoch 32 --- loss:0.258, Epoch accuracy:90.87%, Validation loss:1.102, Validation accuracy:66.90%
# Epoch 33: iteration 106/107
# Epoch 33 --- loss:0.243, Epoch accuracy:91.11%, Validation loss:1.308, Validation accuracy:62.47%
# Epoch 34: iteration 106/107
# Epoch 34 --- loss:0.242, Epoch accuracy:91.11%, Validation loss:1.202, Validation accuracy:62.94%
# Epoch 35: iteration 106/107
# Epoch 35 --- loss:0.237, Epoch accuracy:90.93%, Validation loss:1.224, Validation accuracy:64.80%
# Epoch 36: iteration 106/107
# Epoch 36 --- loss:0.215, Epoch accuracy:91.92%, Validation loss:1.210, Validation accuracy:66.43%
# Epoch 37: iteration 106/107
# Epoch 37 --- loss:0.238, Epoch accuracy:90.85%, Validation loss:1.136, Validation accuracy:67.37%
# Epoch 38: iteration 106/107
# Epoch 38 --- loss:0.232, Epoch accuracy:90.85%, Validation loss:1.315, Validation accuracy:62.70%
# Epoch 39: iteration 106/107
# Epoch 39 --- loss:0.216, Epoch accuracy:91.78%, Validation loss:1.354, Validation accuracy:64.34%
# Epoch 40: iteration 106/107
# Epoch 40 --- loss:0.223, Epoch accuracy:91.57%, Validation loss:1.193, Validation accuracy:65.27%
# Epoch 41: iteration 106/107
# Epoch 41 --- loss:0.176, Epoch accuracy:93.43%, Validation loss:1.092, Validation accuracy:68.07%
# Epoch 42: iteration 106/107
# Epoch 42 --- loss:0.173, Epoch accuracy:93.66%, Validation loss:1.173, Validation accuracy:65.03%
# Epoch 43: iteration 106/107
# Epoch 43 --- loss:0.165, Epoch accuracy:93.52%, Validation loss:1.476, Validation accuracy:62.24%
# Epoch 44: iteration 106/107
# Epoch 44 --- loss:0.167, Epoch accuracy:94.16%, Validation loss:1.336, Validation accuracy:62.94%
# Epoch 45: iteration 106/107
# Epoch 45 --- loss:0.164, Epoch accuracy:94.13%, Validation loss:1.310, Validation accuracy:65.97%
# Epoch 46: iteration 106/107
# Epoch 46 --- loss:0.159, Epoch accuracy:94.39%, Validation loss:1.360, Validation accuracy:65.73%
# Epoch 47: iteration 106/107
# Epoch 47 --- loss:0.162, Epoch accuracy:94.07%, Validation loss:1.227, Validation accuracy:68.07%
# Epoch 48: iteration 106/107
# Epoch 48 --- loss:0.141, Epoch accuracy:94.77%, Validation loss:1.152, Validation accuracy:66.90%
# Epoch 49: iteration 106/107
# Epoch 49 --- loss:0.131, Epoch accuracy:95.50%, Validation loss:1.292, Validation accuracy:66.67%
# Epoch 50: iteration 106/107
# Epoch 50 --- loss:0.132, Epoch accuracy:95.32%, Validation loss:1.503, Validation accuracy:62.94%
# Epoch 51: iteration 106/107
# Epoch 51 --- loss:0.127, Epoch accuracy:95.67%, Validation loss:1.269, Validation accuracy:66.20%
# Epoch 52: iteration 106/107
# Epoch 52 --- loss:0.114, Epoch accuracy:95.96%, Validation loss:1.256, Validation accuracy:66.67%
# Epoch 53: iteration 106/107
# Epoch 53 --- loss:0.111, Epoch accuracy:95.93%, Validation loss:1.180, Validation accuracy:67.60%
# Epoch 54: iteration 106/107
# Epoch 54 --- loss:0.107, Epoch accuracy:96.43%, Validation loss:1.175, Validation accuracy:67.13%
# Epoch 55: iteration 106/107
# Epoch 55 --- loss:0.118, Epoch accuracy:95.99%, Validation loss:1.362, Validation accuracy:66.67%
# Epoch 56: iteration 106/107
# Epoch 56 --- loss:0.126, Epoch accuracy:95.03%, Validation loss:1.250, Validation accuracy:68.76%
# Epoch 57: iteration 106/107
# Epoch 57 --- loss:0.126, Epoch accuracy:95.32%, Validation loss:1.335, Validation accuracy:66.90%
# Epoch 58: iteration 106/107
# Epoch 58 --- loss:0.099, Epoch accuracy:96.77%, Validation loss:1.316, Validation accuracy:67.83%
# Epoch 59: iteration 106/107
# Epoch 59 --- loss:0.115, Epoch accuracy:95.90%, Validation loss:1.436, Validation accuracy:64.57%
# Epoch 60: iteration 106/107
# Epoch 60 --- loss:0.099, Epoch accuracy:96.43%, Validation loss:1.493, Validation accuracy:61.07%
# Epoch 61: iteration 106/107
# Epoch 61 --- loss:0.127, Epoch accuracy:94.86%, Validation loss:1.327, Validation accuracy:64.34%
# Epoch 62: iteration 106/107
# Epoch 62 --- loss:0.096, Epoch accuracy:96.57%, Validation loss:1.379, Validation accuracy:67.37%
# Epoch 63: iteration 106/107
# Epoch 63 --- loss:0.095, Epoch accuracy:96.43%, Validation loss:1.388, Validation accuracy:66.90%
# Epoch 64: iteration 106/107
# Epoch 64 --- loss:0.097, Epoch accuracy:96.40%, Validation loss:1.291, Validation accuracy:67.37%
# Epoch 65: iteration 106/107
# Epoch 65 --- loss:0.098, Epoch accuracy:96.45%, Validation loss:1.583, Validation accuracy:64.57%
# Epoch 66: iteration 106/107
# Epoch 66 --- loss:0.099, Epoch accuracy:95.93%, Validation loss:1.420, Validation accuracy:65.73%
# Epoch 67: iteration 106/107
# Epoch 67 --- loss:0.086, Epoch accuracy:96.92%, Validation loss:1.343, Validation accuracy:66.67%
# Epoch 68: iteration 106/107
# Epoch 68 --- loss:0.072, Epoch accuracy:97.91%, Validation loss:1.270, Validation accuracy:66.90%
# Epoch 69: iteration 106/107
# Epoch 69 --- loss:0.090, Epoch accuracy:96.66%, Validation loss:1.703, Validation accuracy:61.31%
# Epoch 70: iteration 106/107
# Epoch 70 --- loss:0.095, Epoch accuracy:96.77%, Validation loss:1.326, Validation accuracy:68.30%
# Epoch 71: iteration 106/107
# Epoch 71 --- loss:0.085, Epoch accuracy:96.72%, Validation loss:1.299, Validation accuracy:68.07%
# Epoch 72: iteration 106/107
# Epoch 72 --- loss:0.073, Epoch accuracy:97.15%, Validation loss:1.370, Validation accuracy:64.34%
# Epoch 73: iteration 106/107
# Epoch 73 --- loss:0.067, Epoch accuracy:97.79%, Validation loss:1.363, Validation accuracy:67.13%
# Epoch 74: iteration 106/107
# Epoch 74 --- loss:0.069, Epoch accuracy:98.05%, Validation loss:1.391, Validation accuracy:65.97%
# Epoch 75: iteration 106/107
# Epoch 75 --- loss:0.077, Epoch accuracy:97.01%, Validation loss:1.364, Validation accuracy:67.13%
# Epoch 76: iteration 106/107
# Epoch 76 --- loss:0.106, Epoch accuracy:96.19%, Validation loss:1.355, Validation accuracy:68.07%
# Epoch 77: iteration 106/107
# Epoch 77 --- loss:0.082, Epoch accuracy:96.75%, Validation loss:1.238, Validation accuracy:68.07%
# Epoch 78: iteration 106/107
# Epoch 78 --- loss:0.070, Epoch accuracy:97.50%, Validation loss:1.448, Validation accuracy:66.90%
# Epoch 79: iteration 106/107
# Epoch 79 --- loss:0.063, Epoch accuracy:97.91%, Validation loss:1.277, Validation accuracy:70.40%
# Epoch 80: iteration 106/107
# Epoch 80 --- loss:0.062, Epoch accuracy:98.05%, Validation loss:1.252, Validation accuracy:69.70%
# Epoch 81: iteration 106/107
# Epoch 81 --- loss:0.065, Epoch accuracy:97.85%, Validation loss:1.264, Validation accuracy:67.37%
# Epoch 82: iteration 106/107
# Epoch 82 --- loss:0.070, Epoch accuracy:97.41%, Validation loss:1.382, Validation accuracy:66.43%
# Epoch 83: iteration 106/107
# Epoch 83 --- loss:0.061, Epoch accuracy:97.76%, Validation loss:1.317, Validation accuracy:68.30%
# Epoch 84: iteration 106/107
# Epoch 84 --- loss:0.068, Epoch accuracy:97.53%, Validation loss:1.280, Validation accuracy:69.23%
# Epoch 85: iteration 106/107
# Epoch 85 --- loss:0.056, Epoch accuracy:98.05%, Validation loss:1.372, Validation accuracy:66.20%
# Epoch 86: iteration 106/107
# Epoch 86 --- loss:0.048, Epoch accuracy:98.34%, Validation loss:1.456, Validation accuracy:66.20%
# Epoch 87: iteration 106/107
# Epoch 87 --- loss:0.063, Epoch accuracy:97.68%, Validation loss:1.375, Validation accuracy:65.97%
# Epoch 88: iteration 106/107
# Epoch 88 --- loss:0.052, Epoch accuracy:98.29%, Validation loss:1.313, Validation accuracy:69.46%
# Epoch 89: iteration 106/107
# Epoch 89 --- loss:0.082, Epoch accuracy:96.86%, Validation loss:1.290, Validation accuracy:66.43%
# Epoch 90: iteration 106/107
# Epoch 90 --- loss:0.061, Epoch accuracy:97.73%, Validation loss:1.204, Validation accuracy:71.10%
# Epoch 91: iteration 106/107
# Epoch 91 --- loss:0.066, Epoch accuracy:97.59%, Validation loss:1.950, Validation accuracy:60.84%
# Epoch 92: iteration 106/107
# Epoch 92 --- loss:0.072, Epoch accuracy:97.24%, Validation loss:1.462, Validation accuracy:67.60%
# Epoch 93: iteration 106/107
# Epoch 93 --- loss:0.073, Epoch accuracy:96.86%, Validation loss:1.269, Validation accuracy:68.30%
# Epoch 94: iteration 106/107
# Epoch 94 --- loss:0.053, Epoch accuracy:98.05%, Validation loss:1.357, Validation accuracy:69.00%
# Epoch 95: iteration 106/107
# Epoch 95 --- loss:0.038, Epoch accuracy:98.90%, Validation loss:1.437, Validation accuracy:66.90%
# Epoch 96: iteration 106/107
# Epoch 96 --- loss:0.063, Epoch accuracy:97.53%, Validation loss:1.374, Validation accuracy:70.40%
# Epoch 97: iteration 106/107
# Epoch 97 --- loss:0.053, Epoch accuracy:98.26%, Validation loss:1.386, Validation accuracy:66.90%
# Epoch 98: iteration 106/107
# Epoch 98 --- loss:0.067, Epoch accuracy:97.88%, Validation loss:1.296, Validation accuracy:68.53%
# Epoch 99: iteration 106/107
# Epoch 99 --- loss:0.067, Epoch accuracy:97.56%, Validation loss:1.438, Validation accuracy:67.37%
# Epoch 100: iteration 106/107
# Epoch 100 --- loss:0.068, Epoch accuracy:97.50%, Validation loss:1.438, Validation accuracy:65.73%
# Epoch 101: iteration 106/107
# Epoch 101 --- loss:0.045, Epoch accuracy:98.52%, Validation loss:1.284, Validation accuracy:68.53%
# Epoch 102: iteration 106/107
# Epoch 102 --- loss:0.068, Epoch accuracy:97.36%, Validation loss:1.391, Validation accuracy:69.00%
# Epoch 103: iteration 106/107
# Epoch 103 --- loss:0.061, Epoch accuracy:98.11%, Validation loss:1.296, Validation accuracy:69.46%
# Epoch 104: iteration 106/107
# Epoch 104 --- loss:0.053, Epoch accuracy:98.20%, Validation loss:1.579, Validation accuracy:64.57%
# Epoch 105: iteration 106/107
# Epoch 105 --- loss:0.043, Epoch accuracy:98.72%, Validation loss:1.366, Validation accuracy:67.60%
# Epoch 106: iteration 106/107
# Epoch 106 --- loss:0.038, Epoch accuracy:98.78%, Validation loss:1.433, Validation accuracy:64.80%
# Epoch 107: iteration 106/107
# Epoch 107 --- loss:0.046, Epoch accuracy:98.31%, Validation loss:1.440, Validation accuracy:67.37%
# Epoch 108: iteration 106/107
# Epoch 108 --- loss:0.050, Epoch accuracy:98.43%, Validation loss:1.495, Validation accuracy:65.27%
# Epoch 109: iteration 106/107
# Epoch 109 --- loss:0.048, Epoch accuracy:98.46%, Validation loss:1.313, Validation accuracy:70.86%
# Epoch 110: iteration 106/107
# Epoch 110 --- loss:0.065, Epoch accuracy:97.62%, Validation loss:1.311, Validation accuracy:66.90%
# Epoch 111: iteration 106/107
# Epoch 111 --- loss:0.054, Epoch accuracy:98.20%, Validation loss:1.406, Validation accuracy:69.46%
# Epoch 112: iteration 106/107
# Epoch 112 --- loss:0.049, Epoch accuracy:98.29%, Validation loss:1.290, Validation accuracy:69.46%
# Epoch 113: iteration 106/107
# Epoch 113 --- loss:0.035, Epoch accuracy:98.81%, Validation loss:1.378, Validation accuracy:68.07%
# Epoch 114: iteration 106/107
# Epoch 114 --- loss:0.043, Epoch accuracy:98.31%, Validation loss:1.598, Validation accuracy:64.57%
# Epoch 115: iteration 106/107
# Epoch 115 --- loss:0.074, Epoch accuracy:97.09%, Validation loss:1.457, Validation accuracy:67.13%
# Epoch 116: iteration 106/107
# Epoch 116 --- loss:0.067, Epoch accuracy:97.56%, Validation loss:1.384, Validation accuracy:65.97%
# Epoch 117: iteration 106/107
# Epoch 117 --- loss:0.045, Epoch accuracy:98.34%, Validation loss:1.289, Validation accuracy:69.70%
# Epoch 118: iteration 106/107
# Epoch 118 --- loss:0.036, Epoch accuracy:98.75%, Validation loss:1.617, Validation accuracy:64.10%
# Epoch 119: iteration 106/107
# Epoch 119 --- loss:0.041, Epoch accuracy:98.49%, Validation loss:1.200, Validation accuracy:72.03%
# Epoch 120: iteration 106/107
# Epoch 120 --- loss:0.032, Epoch accuracy:98.98%, Validation loss:1.407, Validation accuracy:67.83%
# Epoch 121: iteration 106/107
# Epoch 121 --- loss:0.046, Epoch accuracy:98.34%, Validation loss:1.271, Validation accuracy:68.07%
# Epoch 122: iteration 106/107
# Epoch 122 --- loss:0.051, Epoch accuracy:98.20%, Validation loss:1.464, Validation accuracy:64.34%
# Epoch 123: iteration 106/107
# Epoch 123 --- loss:0.055, Epoch accuracy:97.99%, Validation loss:1.528, Validation accuracy:65.50%
# Epoch 124: iteration 106/107
# Epoch 124 --- loss:0.046, Epoch accuracy:98.37%, Validation loss:1.288, Validation accuracy:71.79%
# Epoch 125: iteration 106/107
# Epoch 125 --- loss:0.044, Epoch accuracy:98.55%, Validation loss:1.281, Validation accuracy:67.60%
# Epoch 126: iteration 106/107
# Epoch 126 --- loss:0.046, Epoch accuracy:98.14%, Validation loss:1.250, Validation accuracy:68.76%
# Epoch 127: iteration 106/107
# Epoch 127 --- loss:0.040, Epoch accuracy:98.52%, Validation loss:1.478, Validation accuracy:66.90%
# Epoch 128: iteration 106/107
# Epoch 128 --- loss:0.065, Epoch accuracy:97.50%, Validation loss:1.229, Validation accuracy:72.03%
# Epoch 129: iteration 106/107
# Epoch 129 --- loss:0.054, Epoch accuracy:97.97%, Validation loss:1.338, Validation accuracy:68.53%
# Epoch 130: iteration 106/107
# Epoch 130 --- loss:0.036, Epoch accuracy:98.87%, Validation loss:1.216, Validation accuracy:71.10%
# Epoch 131: iteration 106/107
# Epoch 131 --- loss:0.035, Epoch accuracy:98.98%, Validation loss:1.287, Validation accuracy:68.76%
# Epoch 132: iteration 106/107
# Epoch 132 --- loss:0.043, Epoch accuracy:98.49%, Validation loss:1.333, Validation accuracy:66.90%
# Epoch 133: iteration 106/107
# Epoch 133 --- loss:0.050, Epoch accuracy:97.91%, Validation loss:1.349, Validation accuracy:66.43%
# Epoch 134: iteration 106/107
# Epoch 134 --- loss:0.034, Epoch accuracy:98.78%, Validation loss:1.311, Validation accuracy:69.70%
# Epoch 135: iteration 106/107
# Epoch 135 --- loss:0.062, Epoch accuracy:97.65%, Validation loss:1.414, Validation accuracy:68.07%
# Epoch 136: iteration 106/107
# Epoch 136 --- loss:0.037, Epoch accuracy:98.69%, Validation loss:1.322, Validation accuracy:68.53%
# Epoch 137: iteration 106/107
# Epoch 137 --- loss:0.058, Epoch accuracy:97.56%, Validation loss:1.491, Validation accuracy:67.37%
# Epoch 138: iteration 106/107
# Epoch 138 --- loss:0.051, Epoch accuracy:98.31%, Validation loss:1.391, Validation accuracy:68.53%
# Epoch 139: iteration 106/107
# Epoch 139 --- loss:0.051, Epoch accuracy:98.20%, Validation loss:1.287, Validation accuracy:70.63%
# Epoch 140: iteration 106/107
# Epoch 140 --- loss:0.037, Epoch accuracy:98.75%, Validation loss:1.351, Validation accuracy:69.93%
# Epoch 141: iteration 106/107
# Epoch 141 --- loss:0.044, Epoch accuracy:98.34%, Validation loss:1.225, Validation accuracy:71.33%
# Epoch 142: iteration 106/107
# Epoch 142 --- loss:0.071, Epoch accuracy:97.38%, Validation loss:1.272, Validation accuracy:69.70%
# Epoch 143: iteration 106/107
# Epoch 143 --- loss:0.043, Epoch accuracy:98.55%, Validation loss:1.375, Validation accuracy:66.67%
# Epoch 144: iteration 106/107
# Epoch 144 --- loss:0.057, Epoch accuracy:97.88%, Validation loss:1.322, Validation accuracy:69.00%
# Epoch 145: iteration 106/107
# Epoch 145 --- loss:0.046, Epoch accuracy:98.37%, Validation loss:1.394, Validation accuracy:67.13%
# Epoch 146: iteration 106/107
# Epoch 146 --- loss:0.048, Epoch accuracy:98.08%, Validation loss:1.245, Validation accuracy:71.33%
# Epoch 147: iteration 106/107
# Epoch 147 --- loss:0.036, Epoch accuracy:98.72%, Validation loss:1.237, Validation accuracy:69.93%
# Epoch 148: iteration 106/107
# Epoch 148 --- loss:0.027, Epoch accuracy:99.13%, Validation loss:1.235, Validation accuracy:70.63%
# Epoch 149: iteration 106/107
# Epoch 149 --- loss:0.036, Epoch accuracy:98.84%, Validation loss:1.309, Validation accuracy:69.00%
# Epoch 150: iteration 106/107
# Epoch 150 --- loss:0.028, Epoch accuracy:99.07%, Validation loss:1.288, Validation accuracy:69.00%
# Epoch 151: iteration 106/107
# Epoch 151 --- loss:0.043, Epoch accuracy:98.02%, Validation loss:1.306, Validation accuracy:68.53%
# Epoch 152: iteration 106/107
# Epoch 152 --- loss:0.033, Epoch accuracy:98.66%, Validation loss:1.206, Validation accuracy:71.56%
# Epoch 153: iteration 106/107
# Epoch 153 --- loss:0.077, Epoch accuracy:97.38%, Validation loss:1.299, Validation accuracy:68.76%
# Epoch 154: iteration 106/107
# Epoch 154 --- loss:0.033, Epoch accuracy:98.95%, Validation loss:1.306, Validation accuracy:70.40%
# Epoch 155: iteration 106/107
# Epoch 155 --- loss:0.044, Epoch accuracy:98.29%, Validation loss:1.297, Validation accuracy:70.86%
# Epoch 156: iteration 106/107
# Epoch 156 --- loss:0.072, Epoch accuracy:97.47%, Validation loss:1.386, Validation accuracy:67.13%
# Epoch 157: iteration 106/107
# Epoch 157 --- loss:0.035, Epoch accuracy:98.92%, Validation loss:1.452, Validation accuracy:66.20%
# Epoch 158: iteration 106/107
# Epoch 158 --- loss:0.046, Epoch accuracy:98.46%, Validation loss:1.538, Validation accuracy:66.20%
# Epoch 159: iteration 106/107
# Epoch 159 --- loss:0.064, Epoch accuracy:97.41%, Validation loss:1.501, Validation accuracy:65.73%
# Epoch 160: iteration 106/107
# Epoch 160 --- loss:0.031, Epoch accuracy:98.92%, Validation loss:1.518, Validation accuracy:66.20%
# Epoch 161: iteration 106/107
# Epoch 161 --- loss:0.050, Epoch accuracy:98.26%, Validation loss:1.464, Validation accuracy:65.97%
# Epoch 162: iteration 106/107
# Epoch 162 --- loss:0.041, Epoch accuracy:98.52%, Validation loss:1.273, Validation accuracy:69.93%
# Epoch 163: iteration 106/107
# Epoch 163 --- loss:0.044, Epoch accuracy:98.26%, Validation loss:1.555, Validation accuracy:66.67%
# Epoch 164: iteration 106/107
# Epoch 164 --- loss:0.076, Epoch accuracy:97.12%, Validation loss:1.494, Validation accuracy:69.00%
# Epoch 165: iteration 106/107
# Epoch 165 --- loss:0.035, Epoch accuracy:98.81%, Validation loss:1.413, Validation accuracy:67.60%
# Epoch 166: iteration 106/107
# Epoch 166 --- loss:0.036, Epoch accuracy:98.55%, Validation loss:1.333, Validation accuracy:68.76%
# Epoch 167: iteration 106/107
# Epoch 167 --- loss:0.079, Epoch accuracy:96.69%, Validation loss:1.475, Validation accuracy:64.34%
# Epoch 168: iteration 106/107
# Epoch 168 --- loss:0.040, Epoch accuracy:98.63%, Validation loss:1.374, Validation accuracy:67.13%
# Epoch 169: iteration 106/107
# Epoch 169 --- loss:0.029, Epoch accuracy:98.84%, Validation loss:1.300, Validation accuracy:69.46%
# Epoch 170: iteration 106/107
# Epoch 170 --- loss:0.049, Epoch accuracy:98.23%, Validation loss:1.376, Validation accuracy:67.60%
# Epoch 171: iteration 106/107
# Epoch 171 --- loss:0.044, Epoch accuracy:98.31%, Validation loss:1.602, Validation accuracy:64.57%
# Epoch 172: iteration 106/107
# Epoch 172 --- loss:0.039, Epoch accuracy:98.58%, Validation loss:1.514, Validation accuracy:66.67%
# Epoch 173: iteration 106/107
# Epoch 173 --- loss:0.026, Epoch accuracy:99.24%, Validation loss:1.335, Validation accuracy:69.23%
# Epoch 174: iteration 106/107
# Epoch 174 --- loss:0.026, Epoch accuracy:99.04%, Validation loss:1.296, Validation accuracy:68.53%
# Epoch 175: iteration 106/107
# Epoch 175 --- loss:0.064, Epoch accuracy:97.44%, Validation loss:1.440, Validation accuracy:68.30%
# Epoch 176: iteration 106/107
# Epoch 176 --- loss:0.049, Epoch accuracy:98.26%, Validation loss:1.291, Validation accuracy:70.86%
# Epoch 177: iteration 106/107
# Epoch 177 --- loss:0.033, Epoch accuracy:98.78%, Validation loss:1.296, Validation accuracy:70.63%
# Epoch 178: iteration 106/107
# Epoch 178 --- loss:0.028, Epoch accuracy:98.95%, Validation loss:1.354, Validation accuracy:68.53%
# Epoch 179: iteration 106/107
# Epoch 179 --- loss:0.026, Epoch accuracy:99.19%, Validation loss:1.358, Validation accuracy:67.60%
# Epoch 180: iteration 106/107
# Epoch 180 --- loss:0.028, Epoch accuracy:99.01%, Validation loss:1.402, Validation accuracy:71.33%
# Epoch 181: iteration 106/107
# Epoch 181 --- loss:0.030, Epoch accuracy:98.98%, Validation loss:1.327, Validation accuracy:68.53%
# Epoch 182: iteration 106/107
# Epoch 182 --- loss:0.042, Epoch accuracy:98.52%, Validation loss:1.368, Validation accuracy:69.00%
# Epoch 183: iteration 106/107
# Epoch 183 --- loss:0.047, Epoch accuracy:98.14%, Validation loss:1.316, Validation accuracy:69.70%
# Epoch 184: iteration 106/107
# Epoch 184 --- loss:0.038, Epoch accuracy:98.69%, Validation loss:1.456, Validation accuracy:67.13%
# Epoch 185: iteration 106/107
# Epoch 185 --- loss:0.081, Epoch accuracy:96.60%, Validation loss:1.603, Validation accuracy:62.24%
# Epoch 186: iteration 106/107
# Epoch 186 --- loss:0.051, Epoch accuracy:98.02%, Validation loss:1.425, Validation accuracy:66.20%
# Epoch 187: iteration 106/107
# Epoch 187 --- loss:0.060, Epoch accuracy:97.70%, Validation loss:1.315, Validation accuracy:69.46%
# Epoch 188: iteration 106/107
# Epoch 188 --- loss:0.049, Epoch accuracy:98.29%, Validation loss:1.306, Validation accuracy:68.53%
# Epoch 189: iteration 106/107
# Epoch 189 --- loss:0.043, Epoch accuracy:98.61%, Validation loss:1.696, Validation accuracy:62.70%
# Epoch 190: iteration 106/107
# Epoch 190 --- loss:0.050, Epoch accuracy:98.11%, Validation loss:1.260, Validation accuracy:70.40%
# Epoch 191: iteration 106/107
# Epoch 191 --- loss:0.034, Epoch accuracy:98.92%, Validation loss:1.487, Validation accuracy:66.43%
# Epoch 192: iteration 106/107
# Epoch 192 --- loss:0.048, Epoch accuracy:98.26%, Validation loss:1.614, Validation accuracy:64.80%
# Epoch 193: iteration 106/107
# Epoch 193 --- loss:0.045, Epoch accuracy:98.11%, Validation loss:1.296, Validation accuracy:69.46%
# Epoch 194: iteration 106/107
# Epoch 194 --- loss:0.044, Epoch accuracy:98.40%, Validation loss:1.279, Validation accuracy:69.93%
# Epoch 195: iteration 106/107
# Epoch 195 --- loss:0.044, Epoch accuracy:98.29%, Validation loss:1.291, Validation accuracy:70.86%
# Epoch 196: iteration 106/107
# Epoch 196 --- loss:0.029, Epoch accuracy:98.92%, Validation loss:1.272, Validation accuracy:70.40%
# Epoch 197: iteration 106/107
# Epoch 197 --- loss:0.066, Epoch accuracy:97.33%, Validation loss:1.346, Validation accuracy:68.76%
# Epoch 198: iteration 106/107
# Epoch 198 --- loss:0.037, Epoch accuracy:98.63%, Validation loss:1.452, Validation accuracy:67.13%
# Epoch 199: iteration 106/107
# Epoch 199 --- loss:0.036, Epoch accuracy:98.63%, Validation loss:1.249, Validation accuracy:69.46%
# Epoch 200: iteration 106/107
# Epoch 200 --- loss:0.028, Epoch accuracy:98.90%, Validation loss:1.252, Validation accuracy:69.70%
# Epoch 201: iteration 106/107
# Epoch 201 --- loss:0.029, Epoch accuracy:98.98%, Validation loss:1.248, Validation accuracy:69.46%
# Epoch 202: iteration 106/107
# Epoch 202 --- loss:0.029, Epoch accuracy:98.90%, Validation loss:1.413, Validation accuracy:67.13%
# Epoch 203: iteration 106/107
# Epoch 203 --- loss:0.029, Epoch accuracy:98.87%, Validation loss:1.371, Validation accuracy:68.30%
# Epoch 204: iteration 106/107
# Epoch 204 --- loss:0.042, Epoch accuracy:98.58%, Validation loss:1.370, Validation accuracy:69.93%
# Epoch 205: iteration 106/107
# Epoch 205 --- loss:0.029, Epoch accuracy:98.81%, Validation loss:1.336, Validation accuracy:70.63%
# Epoch 206: iteration 106/107
# Epoch 206 --- loss:0.037, Epoch accuracy:98.66%, Validation loss:1.308, Validation accuracy:68.07%
# Epoch 207: iteration 106/107
# Epoch 207 --- loss:0.044, Epoch accuracy:98.29%, Validation loss:1.554, Validation accuracy:65.50%
# Epoch 208: iteration 106/107
# Epoch 208 --- loss:0.051, Epoch accuracy:98.23%, Validation loss:1.406, Validation accuracy:66.67%
# Epoch 209: iteration 106/107
# Epoch 209 --- loss:0.057, Epoch accuracy:97.56%, Validation loss:1.617, Validation accuracy:63.87%
# Epoch 210: iteration 106/107
# Epoch 210 --- loss:0.044, Epoch accuracy:98.37%, Validation loss:1.405, Validation accuracy:66.20%
# Epoch 211: iteration 106/107
# Epoch 211 --- loss:0.030, Epoch accuracy:98.87%, Validation loss:1.352, Validation accuracy:68.76%
# Epoch 212: iteration 106/107
# Epoch 212 --- loss:0.042, Epoch accuracy:98.43%, Validation loss:1.448, Validation accuracy:67.37%
# Epoch 213: iteration 106/107
# Epoch 213 --- loss:0.039, Epoch accuracy:98.61%, Validation loss:1.465, Validation accuracy:65.27%
# Epoch 214: iteration 106/107
# Epoch 214 --- loss:0.036, Epoch accuracy:98.61%, Validation loss:1.370, Validation accuracy:69.70%
# Epoch 215: iteration 106/107
# Epoch 215 --- loss:0.090, Epoch accuracy:96.16%, Validation loss:1.613, Validation accuracy:66.90%
# Epoch 216: iteration 106/107
# Epoch 216 --- loss:0.072, Epoch accuracy:96.86%, Validation loss:1.548, Validation accuracy:64.80%
# Epoch 217: iteration 106/107
# Epoch 217 --- loss:0.052, Epoch accuracy:97.85%, Validation loss:1.240, Validation accuracy:69.46%
# Epoch 218: iteration 106/107
# Epoch 218 --- loss:0.047, Epoch accuracy:98.34%, Validation loss:1.311, Validation accuracy:69.70%
# Epoch 219: iteration 106/107
# Epoch 219 --- loss:0.058, Epoch accuracy:97.82%, Validation loss:1.425, Validation accuracy:64.10%
# Epoch 220: iteration 106/107
# Epoch 220 --- loss:0.042, Epoch accuracy:98.46%, Validation loss:1.620, Validation accuracy:62.70%
# Epoch 221: iteration 106/107
# Epoch 221 --- loss:0.026, Epoch accuracy:98.90%, Validation loss:1.244, Validation accuracy:68.76%
# Epoch 222: iteration 106/107
# Epoch 222 --- loss:0.025, Epoch accuracy:99.10%, Validation loss:1.367, Validation accuracy:66.90%
# Epoch 223: iteration 106/107
# Epoch 223 --- loss:0.027, Epoch accuracy:99.16%, Validation loss:1.355, Validation accuracy:67.37%
# Epoch 224: iteration 106/107
# Epoch 224 --- loss:0.054, Epoch accuracy:97.62%, Validation loss:1.306, Validation accuracy:68.30%
# Epoch 225: iteration 106/107
# Epoch 225 --- loss:0.041, Epoch accuracy:98.34%, Validation loss:1.297, Validation accuracy:69.23%
# Epoch 226: iteration 106/107
# Epoch 226 --- loss:0.044, Epoch accuracy:98.29%, Validation loss:1.283, Validation accuracy:73.19%
# Epoch 227: iteration 106/107
# Epoch 227 --- loss:0.051, Epoch accuracy:97.82%, Validation loss:1.301, Validation accuracy:68.53%
# Epoch 228: iteration 106/107
# Epoch 228 --- loss:0.029, Epoch accuracy:98.95%, Validation loss:1.377, Validation accuracy:67.60%
# Epoch 229: iteration 106/107
# Epoch 229 --- loss:0.023, Epoch accuracy:99.22%, Validation loss:1.286, Validation accuracy:70.40%
# Epoch 230: iteration 106/107
# Epoch 230 --- loss:0.024, Epoch accuracy:99.13%, Validation loss:1.460, Validation accuracy:64.57%
# Epoch 231: iteration 106/107
# Epoch 231 --- loss:0.028, Epoch accuracy:98.90%, Validation loss:1.427, Validation accuracy:67.13%
# Epoch 232: iteration 106/107
# Epoch 232 --- loss:0.063, Epoch accuracy:97.65%, Validation loss:1.514, Validation accuracy:65.27%
# Epoch 233: iteration 106/107
# Epoch 233 --- loss:0.032, Epoch accuracy:98.92%, Validation loss:1.460, Validation accuracy:67.37%
# Epoch 234: iteration 106/107
# Epoch 234 --- loss:0.025, Epoch accuracy:99.01%, Validation loss:1.229, Validation accuracy:70.16%
# Epoch 235: iteration 106/107
# Epoch 235 --- loss:0.022, Epoch accuracy:99.13%, Validation loss:1.238, Validation accuracy:69.23%
# Epoch 236: iteration 106/107
# Epoch 236 --- loss:0.017, Epoch accuracy:99.30%, Validation loss:1.360, Validation accuracy:68.30%
# Epoch 237: iteration 106/107
# Epoch 237 --- loss:0.016, Epoch accuracy:99.36%, Validation loss:1.382, Validation accuracy:69.00%
# Epoch 238: iteration 106/107
# Epoch 238 --- loss:0.019, Epoch accuracy:99.24%, Validation loss:1.248, Validation accuracy:69.93%
# Epoch 239: iteration 106/107
# Epoch 239 --- loss:0.046, Epoch accuracy:98.08%, Validation loss:1.668, Validation accuracy:66.43%
# Epoch 240: iteration 106/107
# Epoch 240 --- loss:0.058, Epoch accuracy:97.73%, Validation loss:1.387, Validation accuracy:66.43%
# Epoch 241: iteration 106/107
# Epoch 241 --- loss:0.048, Epoch accuracy:98.08%, Validation loss:1.372, Validation accuracy:68.53%
# Epoch 242: iteration 106/107
# Epoch 242 --- loss:0.078, Epoch accuracy:97.01%, Validation loss:1.300, Validation accuracy:68.76%
# Epoch 243: iteration 106/107
# Epoch 243 --- loss:0.044, Epoch accuracy:98.43%, Validation loss:1.264, Validation accuracy:68.76%
# Epoch 244: iteration 106/107
# Epoch 244 --- loss:0.025, Epoch accuracy:99.16%, Validation loss:1.468, Validation accuracy:67.83%
# Epoch 245: iteration 106/107
# Epoch 245 --- loss:0.029, Epoch accuracy:98.92%, Validation loss:1.341, Validation accuracy:67.83%
# Epoch 246: iteration 106/107
# Epoch 246 --- loss:0.030, Epoch accuracy:98.90%, Validation loss:1.544, Validation accuracy:64.80%
# Epoch 247: iteration 106/107
# Epoch 247 --- loss:0.041, Epoch accuracy:98.29%, Validation loss:1.428, Validation accuracy:65.73%
# Epoch 248: iteration 106/107
# Epoch 248 --- loss:0.038, Epoch accuracy:98.31%, Validation loss:1.276, Validation accuracy:68.30%
# Epoch 249: iteration 106/107
# Epoch 249 --- loss:0.041, Epoch accuracy:98.58%, Validation loss:1.599, Validation accuracy:65.27%
# Epoch 250: iteration 106/107
# Epoch 250 --- loss:0.042, Epoch accuracy:98.29%, Validation loss:1.533, Validation accuracy:68.30%
# Epoch 251: iteration 106/107
# Epoch 251 --- loss:0.046, Epoch accuracy:98.26%, Validation loss:1.429, Validation accuracy:68.30%
# Epoch 252: iteration 106/107
# Epoch 252 --- loss:0.073, Epoch accuracy:97.27%, Validation loss:1.390, Validation accuracy:69.00%
# Epoch 253: iteration 106/107
# Epoch 253 --- loss:0.074, Epoch accuracy:97.01%, Validation loss:1.460, Validation accuracy:64.80%
# Epoch 254: iteration 106/107
# Epoch 254 --- loss:0.034, Epoch accuracy:98.69%, Validation loss:1.528, Validation accuracy:66.20%
# Epoch 255: iteration 106/107
# Epoch 255 --- loss:0.033, Epoch accuracy:98.78%, Validation loss:1.326, Validation accuracy:68.53%
# Epoch 256: iteration 106/107
# Epoch 256 --- loss:0.028, Epoch accuracy:98.92%, Validation loss:1.599, Validation accuracy:64.80%
# Epoch 257: iteration 106/107
# Epoch 257 --- loss:0.023, Epoch accuracy:99.07%, Validation loss:1.272, Validation accuracy:69.00%
# Epoch 258: iteration 106/107
# Epoch 258 --- loss:0.025, Epoch accuracy:99.13%, Validation loss:1.417, Validation accuracy:66.43%
# Epoch 259: iteration 106/107
# Epoch 259 --- loss:0.037, Epoch accuracy:98.40%, Validation loss:1.466, Validation accuracy:66.20%
# Epoch 260: iteration 106/107
# Epoch 260 --- loss:0.053, Epoch accuracy:97.82%, Validation loss:1.454, Validation accuracy:65.27%
# Epoch 261: iteration 106/107
# Epoch 261 --- loss:0.054, Epoch accuracy:97.88%, Validation loss:1.425, Validation accuracy:68.76%
# Epoch 262: iteration 106/107
# Epoch 262 --- loss:0.028, Epoch accuracy:98.78%, Validation loss:1.331, Validation accuracy:66.90%
# Epoch 263: iteration 106/107
# Epoch 263 --- loss:0.046, Epoch accuracy:98.05%, Validation loss:1.367, Validation accuracy:69.00%
# Epoch 264: iteration 106/107
# Epoch 264 --- loss:0.064, Epoch accuracy:97.70%, Validation loss:1.243, Validation accuracy:71.56%
# Epoch 265: iteration 106/107
# Epoch 265 --- loss:0.036, Epoch accuracy:98.61%, Validation loss:1.349, Validation accuracy:68.07%
# Epoch 266: iteration 106/107
# Epoch 266 --- loss:0.027, Epoch accuracy:99.07%, Validation loss:1.381, Validation accuracy:67.60%
# Epoch 267: iteration 106/107
# Epoch 267 --- loss:0.034, Epoch accuracy:98.63%, Validation loss:1.451, Validation accuracy:66.67%
# Epoch 268: iteration 106/107
# Epoch 268 --- loss:0.036, Epoch accuracy:98.69%, Validation loss:1.378, Validation accuracy:66.67%
# Epoch 269: iteration 106/107
# Epoch 269 --- loss:0.040, Epoch accuracy:98.46%, Validation loss:1.406, Validation accuracy:68.30%
# Epoch 270: iteration 106/107
# Epoch 270 --- loss:0.046, Epoch accuracy:98.20%, Validation loss:1.385, Validation accuracy:68.76%
# Epoch 271: iteration 106/107
# Epoch 271 --- loss:0.057, Epoch accuracy:97.62%, Validation loss:1.424, Validation accuracy:68.30%
# Epoch 272: iteration 106/107
# Epoch 272 --- loss:0.038, Epoch accuracy:98.58%, Validation loss:1.575, Validation accuracy:64.10%
# Epoch 273: iteration 106/107
# Epoch 273 --- loss:0.031, Epoch accuracy:98.81%, Validation loss:1.323, Validation accuracy:67.60%
# Epoch 274: iteration 106/107
# Epoch 274 --- loss:0.019, Epoch accuracy:99.24%, Validation loss:1.325, Validation accuracy:68.53%
# Epoch 275: iteration 106/107
# Epoch 275 --- loss:0.036, Epoch accuracy:98.61%, Validation loss:1.694, Validation accuracy:63.40%
# Epoch 276: iteration 106/107
# Epoch 276 --- loss:0.077, Epoch accuracy:97.04%, Validation loss:1.236, Validation accuracy:68.53%
# Epoch 277: iteration 106/107
# Epoch 277 --- loss:0.042, Epoch accuracy:98.29%, Validation loss:1.314, Validation accuracy:67.60%
# Epoch 278: iteration 106/107
# Epoch 278 --- loss:0.060, Epoch accuracy:97.59%, Validation loss:1.426, Validation accuracy:66.90%
# Epoch 279: iteration 106/107
# Epoch 279 --- loss:0.033, Epoch accuracy:98.87%, Validation loss:1.278, Validation accuracy:66.90%
# Epoch 280: iteration 106/107
# Epoch 280 --- loss:0.036, Epoch accuracy:98.49%, Validation loss:1.754, Validation accuracy:64.34%
# Epoch 281: iteration 106/107
# Epoch 281 --- loss:0.051, Epoch accuracy:98.05%, Validation loss:1.542, Validation accuracy:65.50%
# Epoch 282: iteration 106/107
# Epoch 282 --- loss:0.029, Epoch accuracy:99.01%, Validation loss:1.297, Validation accuracy:67.83%
# Epoch 283: iteration 106/107
# Epoch 283 --- loss:0.024, Epoch accuracy:99.10%, Validation loss:1.332, Validation accuracy:67.37%
# Epoch 284: iteration 106/107
# Epoch 284 --- loss:0.041, Epoch accuracy:98.61%, Validation loss:1.325, Validation accuracy:68.76%
# Epoch 285: iteration 106/107
# Epoch 285 --- loss:0.047, Epoch accuracy:98.02%, Validation loss:1.322, Validation accuracy:67.37%
# Epoch 286: iteration 106/107
# Epoch 286 --- loss:0.051, Epoch accuracy:97.99%, Validation loss:1.472, Validation accuracy:64.80%
# Epoch 287: iteration 106/107
# Epoch 287 --- loss:0.060, Epoch accuracy:97.85%, Validation loss:1.310, Validation accuracy:66.43%
# Epoch 288: iteration 106/107
# Epoch 288 --- loss:0.046, Epoch accuracy:98.26%, Validation loss:1.283, Validation accuracy:69.70%
# Epoch 289: iteration 106/107
# Epoch 289 --- loss:0.028, Epoch accuracy:98.92%, Validation loss:1.511, Validation accuracy:64.80%
# Epoch 290: iteration 106/107
# Epoch 290 --- loss:0.029, Epoch accuracy:98.81%, Validation loss:1.706, Validation accuracy:62.00%
# Epoch 291: iteration 106/107
# Epoch 291 --- loss:0.071, Epoch accuracy:97.15%, Validation loss:1.355, Validation accuracy:67.37%
# Epoch 292: iteration 106/107
# Epoch 292 --- loss:0.051, Epoch accuracy:98.23%, Validation loss:1.287, Validation accuracy:70.40%
# Epoch 293: iteration 106/107
# Epoch 293 --- loss:0.033, Epoch accuracy:98.78%, Validation loss:1.568, Validation accuracy:62.94%
# Epoch 294: iteration 106/107
# Epoch 294 --- loss:0.039, Epoch accuracy:98.40%, Validation loss:1.381, Validation accuracy:67.60%
# Epoch 295: iteration 106/107
# Epoch 295 --- loss:0.038, Epoch accuracy:98.52%, Validation loss:1.295, Validation accuracy:67.37%
# Epoch 296: iteration 106/107
# Epoch 296 --- loss:0.022, Epoch accuracy:99.13%, Validation loss:1.247, Validation accuracy:69.46%
# Epoch 297: iteration 106/107
# Epoch 297 --- loss:0.037, Epoch accuracy:98.52%, Validation loss:1.565, Validation accuracy:63.40%
# Epoch 298: iteration 106/107
# Epoch 298 --- loss:0.041, Epoch accuracy:98.26%, Validation loss:1.355, Validation accuracy:66.43%
# Epoch 299: iteration 106/107
# Epoch 299 --- loss:0.033, Epoch accuracy:98.84%, Validation loss:1.428, Validation accuracy:65.97%
# Epoch 300: iteration 106/107
# Epoch 300 --- loss:0.075, Epoch accuracy:96.83%, Validation loss:1.261, Validation accuracy:68.30%
# Epoch 301: iteration 106/107
# Epoch 301 --- loss:0.044, Epoch accuracy:98.46%, Validation loss:1.291, Validation accuracy:70.16%
# Epoch 302: iteration 106/107
# Epoch 302 --- loss:0.055, Epoch accuracy:97.59%, Validation loss:1.343, Validation accuracy:67.83%
# Epoch 303: iteration 106/107
# Epoch 303 --- loss:0.047, Epoch accuracy:98.40%, Validation loss:1.376, Validation accuracy:69.46%
# Epoch 304: iteration 106/107
# Epoch 304 --- loss:0.024, Epoch accuracy:99.07%, Validation loss:1.345, Validation accuracy:66.43%
# Epoch 305: iteration 106/107
# Epoch 305 --- loss:0.027, Epoch accuracy:98.81%, Validation loss:1.339, Validation accuracy:68.30%
# Epoch 306: iteration 106/107
# Epoch 306 --- loss:0.022, Epoch accuracy:99.10%, Validation loss:1.581, Validation accuracy:65.03%
# Epoch 307: iteration 106/107
# Epoch 307 --- loss:0.025, Epoch accuracy:98.92%, Validation loss:1.319, Validation accuracy:67.37%
# Epoch 308: iteration 106/107
# Epoch 308 --- loss:0.047, Epoch accuracy:98.11%, Validation loss:1.559, Validation accuracy:62.00%
# Epoch 309: iteration 106/107
# Epoch 309 --- loss:0.049, Epoch accuracy:97.88%, Validation loss:1.394, Validation accuracy:66.90%
# Epoch 310: iteration 106/107
# Epoch 310 --- loss:0.034, Epoch accuracy:98.69%, Validation loss:1.305, Validation accuracy:68.76%
# Epoch 311: iteration 106/107
# Epoch 311 --- loss:0.077, Epoch accuracy:97.44%, Validation loss:1.578, Validation accuracy:65.50%
# Epoch 312: iteration 106/107
# Epoch 312 --- loss:0.058, Epoch accuracy:97.79%, Validation loss:1.384, Validation accuracy:67.37%
# Epoch 313: iteration 106/107
# Epoch 313 --- loss:0.032, Epoch accuracy:98.92%, Validation loss:1.462, Validation accuracy:65.50%
# Epoch 314: iteration 106/107
# Epoch 314 --- loss:0.036, Epoch accuracy:98.49%, Validation loss:1.348, Validation accuracy:68.07%
# Epoch 315: iteration 106/107
# Epoch 315 --- loss:0.034, Epoch accuracy:98.72%, Validation loss:1.245, Validation accuracy:69.23%
# Epoch 316: iteration 106/107
# Epoch 316 --- loss:0.024, Epoch accuracy:99.10%, Validation loss:1.401, Validation accuracy:67.37%
# Epoch 317: iteration 106/107
# Epoch 317 --- loss:0.017, Epoch accuracy:99.36%, Validation loss:1.291, Validation accuracy:68.07%
# Epoch 318: iteration 106/107
# Epoch 318 --- loss:0.015, Epoch accuracy:99.36%, Validation loss:1.364, Validation accuracy:67.37%
# Epoch 319: iteration 106/107
# Epoch 319 --- loss:0.025, Epoch accuracy:99.01%, Validation loss:1.540, Validation accuracy:65.50%
# Epoch 320: iteration 106/107
# Epoch 320 --- loss:0.022, Epoch accuracy:99.01%, Validation loss:1.330, Validation accuracy:68.30%
# Epoch 321: iteration 106/107
# Epoch 321 --- loss:0.031, Epoch accuracy:98.87%, Validation loss:1.893, Validation accuracy:60.61%
# Epoch 322: iteration 106/107
# Epoch 322 --- loss:0.054, Epoch accuracy:97.82%, Validation loss:1.372, Validation accuracy:70.63%
# Epoch 323: iteration 106/107
# Epoch 323 --- loss:0.021, Epoch accuracy:99.13%, Validation loss:1.319, Validation accuracy:69.70%
# Epoch 324: iteration 106/107
# Epoch 324 --- loss:0.018, Epoch accuracy:99.24%, Validation loss:1.210, Validation accuracy:71.33%
# Epoch 325: iteration 106/107
# Epoch 325 --- loss:0.038, Epoch accuracy:98.46%, Validation loss:1.370, Validation accuracy:69.00%
# Epoch 326: iteration 106/107
# Epoch 326 --- loss:0.032, Epoch accuracy:98.58%, Validation loss:1.439, Validation accuracy:66.90%
# Epoch 327: iteration 106/107
# Epoch 327 --- loss:0.075, Epoch accuracy:96.86%, Validation loss:1.316, Validation accuracy:68.07%
# Epoch 328: iteration 106/107
# Epoch 328 --- loss:0.071, Epoch accuracy:97.06%, Validation loss:1.258, Validation accuracy:69.46%
# Epoch 329: iteration 106/107
# Epoch 329 --- loss:0.032, Epoch accuracy:98.78%, Validation loss:1.293, Validation accuracy:67.37%
# Epoch 330: iteration 106/107
# Epoch 330 --- loss:0.023, Epoch accuracy:99.10%, Validation loss:1.444, Validation accuracy:67.37%
# Epoch 331: iteration 106/107
# Epoch 331 --- loss:0.050, Epoch accuracy:98.08%, Validation loss:1.627, Validation accuracy:61.77%
# Epoch 332: iteration 106/107
# Epoch 332 --- loss:0.035, Epoch accuracy:98.55%, Validation loss:1.354, Validation accuracy:69.00%
# Epoch 333: iteration 106/107
# Epoch 333 --- loss:0.038, Epoch accuracy:98.49%, Validation loss:1.367, Validation accuracy:66.20%
# Epoch 334: iteration 106/107
# Epoch 334 --- loss:0.033, Epoch accuracy:98.75%, Validation loss:1.353, Validation accuracy:66.20%
# Epoch 335: iteration 106/107
# Epoch 335 --- loss:0.025, Epoch accuracy:99.13%, Validation loss:1.306, Validation accuracy:67.83%
# Epoch 336: iteration 106/107
# Epoch 336 --- loss:0.044, Epoch accuracy:98.34%, Validation loss:1.213, Validation accuracy:68.76%
# Epoch 337: iteration 106/107
# Epoch 337 --- loss:0.045, Epoch accuracy:98.23%, Validation loss:1.266, Validation accuracy:70.16%
# Epoch 338: iteration 106/107
# Epoch 338 --- loss:0.024, Epoch accuracy:99.19%, Validation loss:1.261, Validation accuracy:70.16%
# Epoch 339: iteration 106/107
# Epoch 339 --- loss:0.017, Epoch accuracy:99.24%, Validation loss:1.341, Validation accuracy:70.16%
# Epoch 340: iteration 106/107
# Epoch 340 --- loss:0.034, Epoch accuracy:98.58%, Validation loss:1.425, Validation accuracy:65.97%
# Epoch 341: iteration 106/107
# Epoch 341 --- loss:0.041, Epoch accuracy:98.37%, Validation loss:1.269, Validation accuracy:69.70%
# Epoch 342: iteration 106/107
# Epoch 342 --- loss:0.080, Epoch accuracy:96.51%, Validation loss:1.293, Validation accuracy:70.40%
# Epoch 343: iteration 106/107
# Epoch 343 --- loss:0.046, Epoch accuracy:98.29%, Validation loss:1.530, Validation accuracy:63.64%
# Epoch 344: iteration 106/107
# Epoch 344 --- loss:0.062, Epoch accuracy:97.47%, Validation loss:1.497, Validation accuracy:66.20%
# Epoch 345: iteration 106/107
# Epoch 345 --- loss:0.049, Epoch accuracy:98.23%, Validation loss:1.248, Validation accuracy:69.23%
# Epoch 346: iteration 106/107
# Epoch 346 --- loss:0.020, Epoch accuracy:99.30%, Validation loss:1.370, Validation accuracy:67.60%
# Epoch 347: iteration 106/107
# Epoch 347 --- loss:0.039, Epoch accuracy:98.26%, Validation loss:1.106, Validation accuracy:71.79%
# Epoch 348: iteration 106/107
# Epoch 348 --- loss:0.042, Epoch accuracy:98.31%, Validation loss:1.435, Validation accuracy:69.70%
# Epoch 349: iteration 106/107
# Epoch 349 --- loss:0.023, Epoch accuracy:99.16%, Validation loss:1.220, Validation accuracy:69.70%
# Epoch 350: iteration 106/107
# Epoch 350 --- loss:0.035, Epoch accuracy:98.78%, Validation loss:1.269, Validation accuracy:68.76%
# Epoch 351: iteration 106/107
# Epoch 351 --- loss:0.030, Epoch accuracy:98.69%, Validation loss:1.400, Validation accuracy:66.67%
# Epoch 352: iteration 106/107
# Epoch 352 --- loss:0.093, Epoch accuracy:96.40%, Validation loss:1.499, Validation accuracy:65.97%
# Epoch 353: iteration 106/107
# Epoch 353 --- loss:0.063, Epoch accuracy:97.59%, Validation loss:1.276, Validation accuracy:69.70%
# Epoch 354: iteration 106/107
# Epoch 354 --- loss:0.024, Epoch accuracy:99.10%, Validation loss:1.436, Validation accuracy:66.67%
# Epoch 355: iteration 106/107
# Epoch 355 --- loss:0.037, Epoch accuracy:98.66%, Validation loss:1.449, Validation accuracy:67.13%
# Epoch 356: iteration 106/107
# Epoch 356 --- loss:0.040, Epoch accuracy:98.40%, Validation loss:1.458, Validation accuracy:67.37%
# Epoch 357: iteration 106/107
# Epoch 357 --- loss:0.061, Epoch accuracy:97.59%, Validation loss:1.435, Validation accuracy:66.90%
# Epoch 358: iteration 106/107
# Epoch 358 --- loss:0.028, Epoch accuracy:98.87%, Validation loss:1.254, Validation accuracy:69.23%
# Epoch 359: iteration 106/107
# Epoch 359 --- loss:0.030, Epoch accuracy:98.87%, Validation loss:1.461, Validation accuracy:66.43%
# Epoch 360: iteration 106/107
# Epoch 360 --- loss:0.024, Epoch accuracy:99.10%, Validation loss:1.320, Validation accuracy:68.53%
# Epoch 361: iteration 106/107
# Epoch 361 --- loss:0.033, Epoch accuracy:98.81%, Validation loss:1.305, Validation accuracy:66.90%
# Epoch 362: iteration 106/107
# Epoch 362 --- loss:0.043, Epoch accuracy:98.26%, Validation loss:1.299, Validation accuracy:67.83%
# Epoch 363: iteration 106/107
# Epoch 363 --- loss:0.024, Epoch accuracy:99.07%, Validation loss:1.376, Validation accuracy:67.60%
# Epoch 364: iteration 106/107
# Epoch 364 --- loss:0.032, Epoch accuracy:98.72%, Validation loss:1.332, Validation accuracy:66.43%
# Epoch 365: iteration 106/107
# Epoch 365 --- loss:0.043, Epoch accuracy:98.26%, Validation loss:1.273, Validation accuracy:67.13%
# Epoch 366: iteration 106/107
# Epoch 366 --- loss:0.020, Epoch accuracy:99.22%, Validation loss:1.360, Validation accuracy:68.30%
# Epoch 367: iteration 106/107
# Epoch 367 --- loss:0.028, Epoch accuracy:98.92%, Validation loss:1.466, Validation accuracy:64.34%
# Epoch 368: iteration 106/107
# Epoch 368 --- loss:0.021, Epoch accuracy:99.13%, Validation loss:1.476, Validation accuracy:67.83%
# Epoch 369: iteration 106/107
# Epoch 369 --- loss:0.020, Epoch accuracy:99.22%, Validation loss:1.369, Validation accuracy:68.76%
# Epoch 370: iteration 106/107
# Epoch 370 --- loss:0.040, Epoch accuracy:98.26%, Validation loss:1.523, Validation accuracy:65.50%
# Epoch 371: iteration 106/107
# Epoch 371 --- loss:0.027, Epoch accuracy:98.87%, Validation loss:1.286, Validation accuracy:70.63%
# Epoch 372: iteration 106/107
# Epoch 372 --- loss:0.043, Epoch accuracy:98.26%, Validation loss:1.462, Validation accuracy:67.60%
# Epoch 373: iteration 106/107
# Epoch 373 --- loss:0.045, Epoch accuracy:98.08%, Validation loss:1.558, Validation accuracy:64.34%
# Epoch 374: iteration 106/107
# Epoch 374 --- loss:0.057, Epoch accuracy:97.68%, Validation loss:1.342, Validation accuracy:67.83%
# Epoch 375: iteration 106/107
# Epoch 375 --- loss:0.058, Epoch accuracy:97.59%, Validation loss:1.392, Validation accuracy:64.57%
# Epoch 376: iteration 106/107
# Epoch 376 --- loss:0.036, Epoch accuracy:98.46%, Validation loss:1.388, Validation accuracy:69.00%
# Epoch 377: iteration 106/107
# Epoch 377 --- loss:0.040, Epoch accuracy:98.37%, Validation loss:1.285, Validation accuracy:68.53%
# Epoch 378: iteration 106/107
# Epoch 378 --- loss:0.039, Epoch accuracy:98.46%, Validation loss:1.538, Validation accuracy:64.10%
# Epoch 379: iteration 106/107
# Epoch 379 --- loss:0.067, Epoch accuracy:97.01%, Validation loss:1.326, Validation accuracy:66.20%
# Epoch 380: iteration 106/107
# Epoch 380 --- loss:0.031, Epoch accuracy:98.81%, Validation loss:1.617, Validation accuracy:63.64%
# Epoch 381: iteration 106/107
# Epoch 381 --- loss:0.041, Epoch accuracy:98.17%, Validation loss:1.355, Validation accuracy:68.07%
# Epoch 382: iteration 106/107
# Epoch 382 --- loss:0.054, Epoch accuracy:97.94%, Validation loss:1.444, Validation accuracy:69.70%
# Epoch 383: iteration 106/107
# Epoch 383 --- loss:0.034, Epoch accuracy:98.58%, Validation loss:1.261, Validation accuracy:70.40%
# Epoch 384: iteration 106/107
# Epoch 384 --- loss:0.031, Epoch accuracy:98.87%, Validation loss:1.321, Validation accuracy:68.53%
# Epoch 385: iteration 106/107
# Epoch 385 --- loss:0.013, Epoch accuracy:99.36%, Validation loss:1.324, Validation accuracy:66.90%
# Epoch 386: iteration 106/107
# Epoch 386 --- loss:0.016, Epoch accuracy:99.27%, Validation loss:1.440, Validation accuracy:66.67%
# Epoch 387: iteration 106/107
# Epoch 387 --- loss:0.019, Epoch accuracy:99.07%, Validation loss:1.622, Validation accuracy:66.67%
# Epoch 388: iteration 106/107
# Epoch 388 --- loss:0.029, Epoch accuracy:98.78%, Validation loss:1.415, Validation accuracy:66.90%
# Epoch 389: iteration 106/107
# Epoch 389 --- loss:0.034, Epoch accuracy:98.61%, Validation loss:1.384, Validation accuracy:69.23%
# Epoch 390: iteration 106/107
# Epoch 390 --- loss:0.033, Epoch accuracy:98.58%, Validation loss:1.307, Validation accuracy:69.46%
# Epoch 391: iteration 106/107
# Epoch 391 --- loss:0.020, Epoch accuracy:99.16%, Validation loss:1.340, Validation accuracy:70.40%
# Epoch 392: iteration 106/107
# Epoch 392 --- loss:0.044, Epoch accuracy:98.23%, Validation loss:2.167, Validation accuracy:60.37%
# Epoch 393: iteration 106/107
# Epoch 393 --- loss:0.102, Epoch accuracy:96.48%, Validation loss:1.320, Validation accuracy:67.37%
# Epoch 394: iteration 106/107
# Epoch 394 --- loss:0.083, Epoch accuracy:96.89%, Validation loss:1.684, Validation accuracy:60.61%
# Epoch 395: iteration 106/107
# Epoch 395 --- loss:0.048, Epoch accuracy:98.17%, Validation loss:1.343, Validation accuracy:69.23%
# Epoch 396: iteration 106/107
# Epoch 396 --- loss:0.030, Epoch accuracy:98.81%, Validation loss:1.363, Validation accuracy:68.76%
# Epoch 397: iteration 106/107
# Epoch 397 --- loss:0.029, Epoch accuracy:98.78%, Validation loss:1.595, Validation accuracy:66.67%
# Epoch 398: iteration 106/107
# Epoch 398 --- loss:0.058, Epoch accuracy:97.79%, Validation loss:1.408, Validation accuracy:66.20%
# Epoch 399: iteration 106/107
# Epoch 399 --- loss:0.039, Epoch accuracy:98.31%, Validation loss:1.528, Validation accuracy:65.50%
# Epoch 400: iteration 106/107
# Epoch 400 --- loss:0.037, Epoch accuracy:98.72%, Validation loss:1.383, Validation accuracy:65.50%
# Epoch 401: iteration 106/107
# Epoch 401 --- loss:0.023, Epoch accuracy:99.10%, Validation loss:1.226, Validation accuracy:69.23%
# Epoch 402: iteration 106/107
# Epoch 402 --- loss:0.012, Epoch accuracy:99.36%, Validation loss:1.326, Validation accuracy:68.76%
# Epoch 403: iteration 106/107
# Epoch 403 --- loss:0.021, Epoch accuracy:99.10%, Validation loss:1.359, Validation accuracy:68.07%
# Epoch 404: iteration 106/107
# Epoch 404 --- loss:0.039, Epoch accuracy:98.20%, Validation loss:1.667, Validation accuracy:63.64%
# Epoch 405: iteration 106/107
# Epoch 405 --- loss:0.034, Epoch accuracy:98.49%, Validation loss:1.424, Validation accuracy:66.90%
# Epoch 406: iteration 106/107
# Epoch 406 --- loss:0.016, Epoch accuracy:99.22%, Validation loss:1.258, Validation accuracy:69.93%
# Epoch 407: iteration 106/107
# Epoch 407 --- loss:0.015, Epoch accuracy:99.27%, Validation loss:1.320, Validation accuracy:67.60%
# Epoch 408: iteration 106/107
# Epoch 408 --- loss:0.021, Epoch accuracy:99.07%, Validation loss:1.401, Validation accuracy:69.00%
# Epoch 409: iteration 106/107
# Epoch 409 --- loss:0.025, Epoch accuracy:98.98%, Validation loss:1.454, Validation accuracy:64.57%
# Epoch 410: iteration 106/107
# Epoch 410 --- loss:0.043, Epoch accuracy:98.05%, Validation loss:1.829, Validation accuracy:66.20%
# Epoch 411: iteration 106/107
# Epoch 411 --- loss:0.075, Epoch accuracy:97.04%, Validation loss:1.430, Validation accuracy:68.07%
# Epoch 412: iteration 106/107
# Epoch 412 --- loss:0.031, Epoch accuracy:98.69%, Validation loss:1.544, Validation accuracy:66.90%
# Epoch 413: iteration 106/107
# Epoch 413 --- loss:0.037, Epoch accuracy:98.52%, Validation loss:1.419, Validation accuracy:65.97%
# Epoch 414: iteration 106/107
# Epoch 414 --- loss:0.028, Epoch accuracy:98.90%, Validation loss:1.444, Validation accuracy:66.67%
# Epoch 415: iteration 106/107
# Epoch 415 --- loss:0.045, Epoch accuracy:98.20%, Validation loss:1.609, Validation accuracy:66.67%
# Epoch 416: iteration 106/107
# Epoch 416 --- loss:0.048, Epoch accuracy:98.14%, Validation loss:1.557, Validation accuracy:67.60%
# Epoch 417: iteration 106/107
# Epoch 417 --- loss:0.068, Epoch accuracy:97.47%, Validation loss:1.427, Validation accuracy:66.20%
# Epoch 418: iteration 106/107
# Epoch 418 --- loss:0.031, Epoch accuracy:98.61%, Validation loss:1.384, Validation accuracy:66.90%
# Epoch 419: iteration 106/107
# Epoch 419 --- loss:0.039, Epoch accuracy:98.49%, Validation loss:1.350, Validation accuracy:68.53%
# Epoch 420: iteration 106/107
# Epoch 420 --- loss:0.023, Epoch accuracy:99.13%, Validation loss:1.346, Validation accuracy:68.53%
# Epoch 421: iteration 106/107
# Epoch 421 --- loss:0.044, Epoch accuracy:98.29%, Validation loss:1.476, Validation accuracy:68.76%
# Epoch 422: iteration 106/107
# Epoch 422 --- loss:0.084, Epoch accuracy:96.66%, Validation loss:1.359, Validation accuracy:69.00%
# Epoch 423: iteration 106/107
# Epoch 423 --- loss:0.033, Epoch accuracy:98.66%, Validation loss:1.423, Validation accuracy:68.53%
# Epoch 424: iteration 106/107
# Epoch 424 --- loss:0.017, Epoch accuracy:99.30%, Validation loss:1.272, Validation accuracy:70.86%
# Epoch 425: iteration 106/107
# Epoch 425 --- loss:0.027, Epoch accuracy:98.90%, Validation loss:1.261, Validation accuracy:70.16%
# Epoch 426: iteration 106/107
# Epoch 426 --- loss:0.020, Epoch accuracy:99.22%, Validation loss:1.406, Validation accuracy:68.76%
# Epoch 427: iteration 106/107
# Epoch 427 --- loss:0.018, Epoch accuracy:99.16%, Validation loss:1.486, Validation accuracy:68.07%
# Epoch 428: iteration 106/107
# Epoch 428 --- loss:0.028, Epoch accuracy:98.84%, Validation loss:1.534, Validation accuracy:67.13%
# Epoch 429: iteration 106/107
# Epoch 429 --- loss:0.030, Epoch accuracy:98.78%, Validation loss:1.367, Validation accuracy:69.23%
# Epoch 430: iteration 106/107
# Epoch 430 --- loss:0.021, Epoch accuracy:99.13%, Validation loss:1.539, Validation accuracy:67.13%
# Epoch 431: iteration 106/107
# Epoch 431 --- loss:0.076, Epoch accuracy:96.45%, Validation loss:1.468, Validation accuracy:66.20%
# Epoch 432: iteration 106/107
# Epoch 432 --- loss:0.029, Epoch accuracy:98.90%, Validation loss:1.536, Validation accuracy:67.13%
# Epoch 433: iteration 106/107
# Epoch 433 --- loss:0.019, Epoch accuracy:99.33%, Validation loss:1.404, Validation accuracy:68.53%
# Epoch 434: iteration 106/107
# Epoch 434 --- loss:0.031, Epoch accuracy:98.69%, Validation loss:1.434, Validation accuracy:66.20%
# Epoch 435: iteration 106/107
# Epoch 435 --- loss:0.030, Epoch accuracy:98.78%, Validation loss:1.422, Validation accuracy:67.37%
# Epoch 436: iteration 106/107
# Epoch 436 --- loss:0.016, Epoch accuracy:99.27%, Validation loss:1.396, Validation accuracy:67.83%
# Epoch 437: iteration 106/107
# Epoch 437 --- loss:0.030, Epoch accuracy:98.84%, Validation loss:1.488, Validation accuracy:68.30%
# Epoch 438: iteration 106/107
# Epoch 438 --- loss:0.062, Epoch accuracy:97.68%, Validation loss:1.371, Validation accuracy:69.46%
# Epoch 439: iteration 106/107
# Epoch 439 --- loss:0.033, Epoch accuracy:98.75%, Validation loss:1.626, Validation accuracy:62.24%
# Epoch 440: iteration 106/107
# Epoch 440 --- loss:0.043, Epoch accuracy:98.14%, Validation loss:1.876, Validation accuracy:60.37%
# Epoch 441: iteration 106/107
# Epoch 441 --- loss:0.082, Epoch accuracy:96.89%, Validation loss:1.429, Validation accuracy:70.63%
# Epoch 442: iteration 106/107
# Epoch 442 --- loss:0.034, Epoch accuracy:98.55%, Validation loss:1.521, Validation accuracy:65.50%
# Epoch 443: iteration 106/107
# Epoch 443 --- loss:0.044, Epoch accuracy:98.26%, Validation loss:1.283, Validation accuracy:68.76%
# Epoch 444: iteration 106/107
# Epoch 444 --- loss:0.036, Epoch accuracy:98.58%, Validation loss:1.598, Validation accuracy:67.13%
# Epoch 445: iteration 106/107
# Epoch 445 --- loss:0.032, Epoch accuracy:98.69%, Validation loss:1.555, Validation accuracy:66.90%
# Epoch 446: iteration 106/107
# Epoch 446 --- loss:0.035, Epoch accuracy:98.63%, Validation loss:1.395, Validation accuracy:67.37%
# Epoch 447: iteration 106/107
# Epoch 447 --- loss:0.035, Epoch accuracy:98.58%, Validation loss:1.353, Validation accuracy:69.46%
# Epoch 448: iteration 106/107
# Epoch 448 --- loss:0.028, Epoch accuracy:98.84%, Validation loss:1.484, Validation accuracy:67.60%
# Epoch 449: iteration 106/107
# Epoch 449 --- loss:0.037, Epoch accuracy:98.40%, Validation loss:1.558, Validation accuracy:66.67%
# Epoch 450: iteration 106/107
# Epoch 450 --- loss:0.045, Epoch accuracy:98.29%, Validation loss:1.456, Validation accuracy:67.60%
# Epoch 451: iteration 106/107
# Epoch 451 --- loss:0.049, Epoch accuracy:98.02%, Validation loss:1.438, Validation accuracy:67.37%
# Epoch 452: iteration 106/107
# Epoch 452 --- loss:0.043, Epoch accuracy:98.11%, Validation loss:1.506, Validation accuracy:66.90%
# Epoch 453: iteration 106/107
# Epoch 453 --- loss:0.039, Epoch accuracy:98.37%, Validation loss:1.473, Validation accuracy:67.60%
# Epoch 454: iteration 106/107
# Epoch 454 --- loss:0.034, Epoch accuracy:98.69%, Validation loss:1.340, Validation accuracy:68.53%
# Epoch 455: iteration 106/107
# Epoch 455 --- loss:0.025, Epoch accuracy:99.07%, Validation loss:1.283, Validation accuracy:70.86%
# Epoch 456: iteration 106/107
# Epoch 456 --- loss:0.018, Epoch accuracy:99.27%, Validation loss:1.499, Validation accuracy:68.76%
# Epoch 457: iteration 106/107
# Epoch 457 --- loss:0.079, Epoch accuracy:96.60%, Validation loss:1.575, Validation accuracy:62.70%
# Epoch 458: iteration 106/107
# Epoch 458 --- loss:0.049, Epoch accuracy:98.05%, Validation loss:1.530, Validation accuracy:66.67%
# Epoch 459: iteration 106/107
# Epoch 459 --- loss:0.019, Epoch accuracy:99.30%, Validation loss:1.502, Validation accuracy:65.97%
# Epoch 460: iteration 106/107
# Epoch 460 --- loss:0.017, Epoch accuracy:99.36%, Validation loss:1.476, Validation accuracy:69.93%
# Epoch 461: iteration 106/107
# Epoch 461 --- loss:0.020, Epoch accuracy:99.22%, Validation loss:1.540, Validation accuracy:65.73%
# Epoch 462: iteration 106/107
# Epoch 462 --- loss:0.040, Epoch accuracy:98.46%, Validation loss:1.458, Validation accuracy:68.30%
# Epoch 463: iteration 106/107
# Epoch 463 --- loss:0.039, Epoch accuracy:98.31%, Validation loss:1.601, Validation accuracy:66.90%
# Epoch 464: iteration 106/107
# Epoch 464 --- loss:0.063, Epoch accuracy:97.38%, Validation loss:1.549, Validation accuracy:67.13%
# Epoch 465: iteration 106/107
# Epoch 465 --- loss:0.022, Epoch accuracy:98.98%, Validation loss:1.489, Validation accuracy:67.83%
# Epoch 466: iteration 106/107
# Epoch 466 --- loss:0.024, Epoch accuracy:99.04%, Validation loss:1.559, Validation accuracy:66.90%
# Epoch 467: iteration 106/107
# Epoch 467 --- loss:0.015, Epoch accuracy:99.27%, Validation loss:1.530, Validation accuracy:67.13%
# Epoch 468: iteration 106/107
# Epoch 468 --- loss:0.036, Epoch accuracy:98.31%, Validation loss:1.413, Validation accuracy:66.20%
# Epoch 469: iteration 106/107
# Epoch 469 --- loss:0.044, Epoch accuracy:98.17%, Validation loss:1.522, Validation accuracy:66.43%
# Epoch 470: iteration 106/107
# Epoch 470 --- loss:0.038, Epoch accuracy:98.31%, Validation loss:1.433, Validation accuracy:65.73%
# Epoch 471: iteration 106/107
# Epoch 471 --- loss:0.021, Epoch accuracy:99.13%, Validation loss:1.484, Validation accuracy:67.13%
# Epoch 472: iteration 106/107
# Epoch 472 --- loss:0.024, Epoch accuracy:99.01%, Validation loss:1.810, Validation accuracy:63.40%
# Epoch 473: iteration 106/107
# Epoch 473 --- loss:0.032, Epoch accuracy:98.69%, Validation loss:1.423, Validation accuracy:67.37%
# Epoch 474: iteration 106/107
# Epoch 474 --- loss:0.011, Epoch accuracy:99.48%, Validation loss:1.442, Validation accuracy:68.76%
# Epoch 475: iteration 106/107
# Epoch 475 --- loss:0.010, Epoch accuracy:99.42%, Validation loss:1.427, Validation accuracy:68.53%
# Epoch 476: iteration 106/107
# Epoch 476 --- loss:0.014, Epoch accuracy:99.30%, Validation loss:1.536, Validation accuracy:67.37%
# Epoch 477: iteration 106/107
# Epoch 477 --- loss:0.027, Epoch accuracy:98.78%, Validation loss:1.575, Validation accuracy:65.97%
# Epoch 478: iteration 106/107
# Epoch 478 --- loss:0.020, Epoch accuracy:99.10%, Validation loss:1.489, Validation accuracy:68.30%
# Epoch 479: iteration 106/107
# Epoch 479 --- loss:0.045, Epoch accuracy:98.02%, Validation loss:1.636, Validation accuracy:68.76%
# Epoch 480: iteration 106/107
# Epoch 480 --- loss:0.067, Epoch accuracy:97.36%, Validation loss:1.349, Validation accuracy:68.76%
# Epoch 481: iteration 106/107
# Epoch 481 --- loss:0.051, Epoch accuracy:97.82%, Validation loss:1.458, Validation accuracy:66.43%
# Epoch 482: iteration 106/107
# Epoch 482 --- loss:0.024, Epoch accuracy:99.07%, Validation loss:1.455, Validation accuracy:67.37%
# Epoch 483: iteration 106/107
# Epoch 483 --- loss:0.045, Epoch accuracy:98.05%, Validation loss:1.526, Validation accuracy:65.03%
# Epoch 484: iteration 106/107
# Epoch 484 --- loss:0.051, Epoch accuracy:98.20%, Validation loss:1.682, Validation accuracy:63.17%
# Epoch 485: iteration 106/107
# Epoch 485 --- loss:0.071, Epoch accuracy:97.18%, Validation loss:1.856, Validation accuracy:63.64%
# Epoch 486: iteration 106/107
# Epoch 486 --- loss:0.052, Epoch accuracy:98.08%, Validation loss:1.467, Validation accuracy:65.97%
# Epoch 487: iteration 106/107
# Epoch 487 --- loss:0.017, Epoch accuracy:99.33%, Validation loss:1.357, Validation accuracy:69.00%
# Epoch 488: iteration 106/107
# Epoch 488 --- loss:0.056, Epoch accuracy:97.79%, Validation loss:1.469, Validation accuracy:65.97%
# Epoch 489: iteration 106/107
# Epoch 489 --- loss:0.084, Epoch accuracy:96.66%, Validation loss:1.251, Validation accuracy:68.07%
# Epoch 490: iteration 106/107
# Epoch 490 --- loss:0.058, Epoch accuracy:97.53%, Validation loss:1.376, Validation accuracy:69.00%
# Epoch 491: iteration 106/107
# Epoch 491 --- loss:0.024, Epoch accuracy:99.04%, Validation loss:1.444, Validation accuracy:69.00%
# Epoch 492: iteration 106/107
# Epoch 492 --- loss:0.027, Epoch accuracy:98.92%, Validation loss:1.505, Validation accuracy:66.43%
# Epoch 493: iteration 106/107
# Epoch 493 --- loss:0.017, Epoch accuracy:99.33%, Validation loss:1.398, Validation accuracy:69.00%
# Epoch 494: iteration 106/107
# Epoch 494 --- loss:0.017, Epoch accuracy:99.27%, Validation loss:1.447, Validation accuracy:68.53%
# Epoch 495: iteration 106/107
# Epoch 495 --- loss:0.019, Epoch accuracy:99.22%, Validation loss:1.461, Validation accuracy:68.76%
# Epoch 496: iteration 106/107
# Epoch 496 --- loss:0.021, Epoch accuracy:99.01%, Validation loss:1.360, Validation accuracy:69.93%
# Epoch 497: iteration 106/107
# Epoch 497 --- loss:0.031, Epoch accuracy:98.63%, Validation loss:1.397, Validation accuracy:67.13%
# Epoch 498: iteration 106/107
# Epoch 498 --- loss:0.018, Epoch accuracy:99.22%, Validation loss:1.374, Validation accuracy:69.00%
# Epoch 499: iteration 106/107
# Epoch 499 --- loss:0.016, Epoch accuracy:99.22%, Validation loss:1.370, Validation accuracy:70.16%

# %% [markdown]
# # Check the Loss Curve's Behaviour
# Let's see if we missed something egregious during training. Note that validation sets achieved 78-82% accuracy depending on the random split of data (checked after tuning; random seed was specified before splitting data while tuning the model).

# %%
plt.title('Loss Curve')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %% [markdown]
# Looks good. Past about 78% validation accuracy, the model begins to overfit on the training set. Note that I ran the final model longer than necessary (500 epochs/20 minutes, vs the 200 epochs/8 minutes it takes to train to convergence as trained on a K80 from Google Colab).

# %% [markdown]
# # Load the Trained Model from Checkpoint for Evaluation

# %%
# pick load folder  
load_folder = '/content/gdrive/My Drive/DL/models/checkpoints'  

# pick the epoch to load
epoch = '429'
model_name = f'parallel_all_you_wantFINAL-{epoch}.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary 
model = parallel_all_you_want(len(emotions_dict))
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-77-5b4006ebc256> in <module>
#      11 ## instantiate empty model and populate with params from binary
#      12 model = parallel_all_you_want(len(emotions_dict))
# ---> 13 load_checkpoint(optimizer, model, load_path)
#      14
#      15 print(f'Loaded model from {load_path}')
#
# <ipython-input-66-887d151f28c1> in load_checkpoint(optimizer, model, filename)
#      10
#      11 def load_checkpoint(optimizer, model, filename):
# ---> 12     checkpoint_dict = torch.load(filename)
#      13     epoch = checkpoint_dict['epoch']
#      14     model.load_state_dict(checkpoint_dict['model'])
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     697         pickle_load_args['encoding'] = 'utf-8'
#     698
# --> 699     with _open_file_like(f, 'rb') as opened_file:
#     700         if _is_zipfile(opened_file):
#     701             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/DL/models/checkpoints/parallel_all_you_wantFINAL-429.pkl'

# %% [markdown]
# # Evaluate the Model on Hold-Out Test Set
# Fingers crossed for generalizability.

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)
# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.float,device=device)

# Get the model's performance metrics using the validation function we defined
test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-83-504f55fc7d4b> in <module>
#       7
#       8 # Get the model's performance metrics using the validation function we defined
# ----> 9 test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)
#      10
#      11 print(f'Test accuracy is {test_acc:.2f}%')
#
# <ipython-input-65-6c183c95585f> in validate(X, Y)
#      10
#      11             # get the model's predictions on the validation set
# ---> 12             output_logits, output_softmax = model(X)
#      13             predictions = torch.argmax(output_softmax,dim=1)
#      14
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-60-687bcc8796f7> in forward(self, x)
#     130         # create final feature embedding from 1st convolutional layer
#     131         # input features pased through 4 sequential 2D convolutional layers
# --> 132         conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
#     133
#     134         # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     455
#     456     def forward(self, input: Tensor) -> Tensor:
# --> 457         return self._conv_forward(input, self.weight, self.bias)
#     458
#     459 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     452                             _pair(0), self.dilation, self.groups)
#     453         return F.conv2d(input, weight, bias, self.stride,
# --> 454                         self.padding, self.dilation, self.groups)
#     455
#     456     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same

# %% [markdown]
# Not too shabby. Past epoch 200, test accuracy is between 75-80%; past epoch 400, test accuracy is between 77-80%; the final few epochs' test accuracy is between 78-80% - so there is a marginal amount of learning going on at the very end.
#
# For some reference points: **[A May 2020 paper](https://www.sciencedirect.com/science/article/abs/pii/S1746809420300501) claims to have achieved a "new SOTA" on RAVDESS speech audio with 71.61% accuracy on 8 emotions**, while [another May 2020 paper](https://ieeexplore.ieee.org/document/9122698) claims to have achieved the "new SOTA" with an 90% F1 score on 8 emotions. Both use CNN architectures. However, the paper reporting 90% F1 score is inflated by testing on training samples: [See the GitHub issue on this paper.](https://github.com/marcogdepinto/emotion-classification-from-audio-files/issues/11)
#
# From the author with a 90% score: _"Also, the previous versions of this work used audio features extracted from the videos of the RAVDESS dataset. This particular part of the pipeline has been removed because it was shuffling very similar files in the training and test sets, boosting accuracy of the model as a consequence (overfitting)."_
#
# The author has augmented the RAVDESS speech audio dataset with speech extracted from video data from RAVDESS - so the **dataset with 90% accuracy contained duplicate samples _before_ being split into training and test sets, causing leakage of test samples into the training set.** For reference, I achieved a 97% accuracy with my model when I similarly augmented the dataset with duplicate speech audio before splitting data. **I corrected this data-leakage issue by augmenting data only _after_ splitting into train/validation/test sets.**
#
# This is an excellent example of "if it's too good to be true". More conservative estimates are more likely to be reproducible, in my opinion.

# %% [markdown]
# # Analyze Performance on Test Set

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions.cpu().numpy()
# use labels from test set
emotions_groundtruth = y_test

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in emotions_dict.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-ccdd3f6f934f> in <module>
#       3
#       4 # because model tested on GPU, move prediction tensor to CPU then convert to array
# ----> 5 predicted_emotions = predicted_emotions.cpu().numpy()
#       6 # use labels from test set
#       7 emotions_groundtruth = y_test
#
# NameError: name 'predicted_emotions' is not defined

# %% [markdown]
# **Unsurprising results - the model has trouble differentiating between 'neutral' and 'calm', and between 'disgust' and 'angry'.**
#
# If a human were asked to differentiate disgust and anger, getting 49/60 correct and 11/60 wrong wouldn't be too bad (these are the scores for 'disgust' from the above matrix).
#
# Other predictable results include confusion of 'sad' for 'disgust'. It's perhaps surprising that 'fearful' is confused for 'happy' as often as it is for 'sad' or 'disgust' - perhaps it is because fear is a truly multifaceted emotion.
#
# Based on this, I would compare in finer detail the features of confused emotions and see if there are any differences at all - and how to capture them. For real-world data, it would be much more productive to perform sentiment analysis on the spoken words translated to text, and consider that in our final evaluation.

# %% [markdown]
# # Conclusion
# ---------------
# Advances of the last 5 years involving upgrades to the autoencoder scheme have lead to the RNN, the upgraded LSTM-RNN, bidirectional LSTM-RNNs, and eventually to LSTM-RNNs with Attention layers to give profound temporal expressivity to the latent space of sequentially encoded data. The Transformer has built on this by taking advantage of parallelized self-attention layers to provide an almost truly global temporal representation of sequential data.
#
# Today, carefully thought out architecture building on these blocks leads to reasonable training times and excellent generalizability. We combine the CNN for spatial feature representation and the Transformer for temporal feature representation, and  augment the training data by increasing variation in the training dataset to reduce overfitting.
#
# CNNs are still the standard for encoding representations of spatial data. A CNN's filters' kernel sizes are important to both performance and accuracy, especially considering recent paradigms using smaller maxpool kernels such as those of the 3x3 strided 1 kernels in [VGGNet](https://arxiv.org/pdf/1409.1556.pdf), in contrast to the 11x11 stride 4 kernels as in the [AlexNet paper](https://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf).
#
# When we added convolutional and transformer layers beyond what was used here, that actually decreased test accuracy. Only as much complexity is warranted as is needed for generalizability. Although CNNs are good for images and transformers for sequential data, recently emerging paradigms (such as in this notebook) show that these networks are perfectly cross-applicable given careful thought.
#
# CNNs are powerful. Transformers work beautifully. They're even better together. Gone are the days of the LSTM-RNN.
#
# If you got this far, I sincerely appreciate your taking the time to do so. Feel free to drop me a line at ilzenkov@gmail.com with any feedback or questions you may have.

# %% [markdown]
# # References
# --------------
# - Ba et al, 2016. Layer Normalization. https://arxiv.org/abs/1607.06450
# - Bahdanau et al, 2015. https://arxiv.org/pdf/1409.0473.pdf
# - Cheng et al, 2016. Long Short-Term Memory-Networks for Machine Reading. https://arxiv.org/pdf/1601.06733.pdf
# - He et al, 2015. Deep Residual Learning for Image Recognition. https://arxiv.org/abs/1512.03385
# - Ioffe, Szegedy, 2015. Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift. https://arxiv.org/abs/1502.03167
# - Krizhevsky et al, 2017. ImageNet Classification with Deep Convolutional Neural Networks. https://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf
# - LeCunn et al, 1998. Gradient-Based Learning Applied to Document Recognition. http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf
# - Li et al, 2018. Visualizing the Loss Landscape of Neural Nets. https://papers.nips.cc/paper/7875-visualizing-the-loss-landscape-of-neural-nets.pdf
# - Masters and Luschi, 2018. Revisiting Small Batch Training for Deep Neural Networks. https://arxiv.org/abs/1804.07612
# - Peng et al, 2017. Large Kernel Matters —— Improve Semantic Segmentation by Global Convolutional Network. https://arxiv.org/pdf/1703.02719.pdf
# - Santurkar et al, 2019. How Does Batch Normalization Help Optimization? https://arxiv.org/pdf/1805.11604.pdf
# - Simonyan and Zisserman, 2015. Very Deep Convolutional Networks for Large-Scale Image Recognition. https://arxiv.org/pdf/1409.1556.pdf
# - Srivastava et al, 2014. Dropout: A Simple Way to Prevent Neural Networks from Overfitting. https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf
# - Ulyanov et al, 2017. Instance Normalization: The Missing Ingredient for Fast Stylization. https://arxiv.org/pdf/1607.08022.pdf
# - Vaswani et al, 2017. Attention Is All You Need. https://arxiv.org/abs/1706.03762
# - Wilson et al, 2017. The Marginal Value of Adaptive Gradient Methods in Machine Learning. https://arxiv.org/abs/1705.08292
#
# - Christopher Olah's Blog; Neural Networks, Types, and Functional Programming: http://colah.github.io/posts/2015-09-NN-Types-FP/
# - Lilian Weng's blog on Attention Mechanisms: https://lilianweng.github.io/lil-log/2018/06/24/attention-attention.html
# - Stanford Autoencoder tutorial: http://ufldl.stanford.edu/tutorial/unsupervised/Autoencoders/
# - Stanford CNN Tutorial: http://ufldl.stanford.edu/tutorial/supervised/FeatureExtractionUsingConvolution/
# - Stanford's CS231n: https://cs231n.github.io/convolutional-networks/
# - U of T CSC2515, Optimization: https://www.cs.toronto.edu/~hinton/csc2515/notes/lec6tutorial.pdf
